# %% [markdown]
# ### Dataset 1: Analyzing Opioid Prescription Rates by State and Provider Type
#
# Implementing K-Means clustering and naive bayes classification to explore provider presecription patterns by state and specialty.
#
# #### Data Cleaning

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.naive_bayes import MultinomialNB

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.preprocessing import OrdinalEncoder

# %%
## load data and examine head of data
import pandas as pd
filename = "prescription_providers.csv"
df = pd.read_csv(filename)
df.head()
# Out:
#    Prscrbr_NPI Prscrbr_Last_Org_Name Prscrbr_First_Name Prscrbr_MI  \
# 0   1003000126             Enkeshafi            Ardalan        NaN
# 1   1003000142                Khalil             Rashid        NaN
# 2   1003000167               Escobar              Julio          E
# 3   1003000423               Velotta           Jennifer          A
# 4   1003000480             Rothchild              Kevin          B
#
#   Prscrbr_Crdntls Prscrbr_Ent_Cd                 Prscrbr_St1 Prscrbr_St2  \
# 0            M.D.              I   6410 Rockledge Dr Ste 304         NaN
# 1            M.D.              I  4126 N Holland Sylvania Rd   Suite 220
# 2             DDS              I              5 Pine Cone Rd         NaN
# 3            M.D.              I            11100 Euclid Ave         NaN
# 4              MD              I            12605 E 16th Ave         NaN
#
#   Prscrbr_City Prscrbr_State_Abrvtn  ...  Bene_Male_Cnt  Bene_Race_Wht_Cnt  \
# 0     Bethesda                   MD  ...           51.0               99.0
# 1       Toledo                   OH  ...          183.0              277.0
# 2       Dayton                   NV  ...           25.0               45.0
# 3    Cleveland                   OH  ...            NaN               54.0
# 4       Aurora                   CO  ...            NaN                NaN
#
#    Bene_Race_Black_Cnt Bene_Race_Api_Cnt Bene_Race_Hspnc_Cnt  \
# 0                 20.0              21.0                 NaN
# 1                184.0               NaN                26.0
# 2                  0.0               0.0                 NaN
# 3                  NaN               0.0                 NaN
# 4                  NaN               NaN                 NaN
#
#   Bene_Race_Natind_Cnt Bene_Race_Othr_Cnt  Bene_Dual_Cnt  Bene_Ndual_Cnt  \
# 0                  0.0                NaN           62.0            93.0
# 1                  NaN               12.0          289.0           213.0
# 2                  0.0                NaN            NaN             NaN
# 3                  0.0                NaN           17.0            47.0
# 4                  0.0                0.0            NaN             NaN
#
#    Bene_Avg_Risk_Scre
# 0            2.059633
# 1            1.903775
# 2            1.139187
# 3            0.880259
# 4            1.797038
#
# [5 rows x 84 columns]

# %%
df.shape
# Out:
# (1332309, 84)

# %%
print(df.columns)
# Out:
# Index(['Prscrbr_NPI', 'Prscrbr_Last_Org_Name', 'Prscrbr_First_Name',
#        'Prscrbr_MI', 'Prscrbr_Crdntls', 'Prscrbr_Ent_Cd', 'Prscrbr_St1',
#        'Prscrbr_St2', 'Prscrbr_City', 'Prscrbr_State_Abrvtn',
#        'Prscrbr_State_FIPS', 'Prscrbr_zip5', 'Prscrbr_RUCA',
#        'Prscrbr_RUCA_Desc', 'Prscrbr_Cntry', 'Prscrbr_Type',
#        'Prscrbr_Type_Src', 'Tot_Clms', 'Tot_30day_Fills', 'Tot_Drug_Cst',
#        'Tot_Day_Suply', 'Tot_Benes', 'GE65_Sprsn_Flag', 'GE65_Tot_Clms',
#        'GE65_Tot_30day_Fills', 'GE65_Tot_Drug_Cst', 'GE65_Tot_Day_Suply',
#        'GE65_Bene_Sprsn_Flag', 'GE65_Tot_Benes', 'Brnd_Sprsn_Flag',
#        'Brnd_Tot_Clms', 'Brnd_Tot_Drug_Cst', 'Gnrc_Sprsn_Flag',
#        'Gnrc_Tot_Clms', 'Gnrc_Tot_Drug_Cst', 'Othr_Sprsn_Flag',
#        'Othr_Tot_Clms', 'Othr_Tot_Drug_Cst', 'MAPD_Sprsn_Flag',
#        'MAPD_Tot_Clms', 'MAPD_Tot_Drug_Cst', 'PDP_Sprsn_Flag', 'PDP_Tot_Clms',
#        'PDP_Tot_Drug_Cst', 'LIS_Sprsn_Flag', 'LIS_Tot_Clms', 'LIS_Drug_Cst',
#        'NonLIS_Sprsn_Flag', 'NonLIS_Tot_Clms', 'NonLIS_Drug_Cst',
#        'Opioid_Tot_Clms', 'Opioid_Tot_Drug_Cst', 'Opioid_Tot_Suply',
#        'Opioid_Tot_Benes', 'Opioid_Prscrbr_Rate', 'Opioid_LA_Tot_Clms',
#        'Opioid_LA_Tot_Drug_Cst', 'Opioid_LA_Tot_Suply', 'Opioid_LA_Tot_Benes',
#        'Opioid_LA_Prscrbr_Rate', 'Antbtc_Tot_Clms', 'Antbtc_Tot_Drug_Cst',
#        'Antbtc_Tot_Benes', 'Antpsyct_GE65_Sprsn_Flag',
#        'Antpsyct_GE65_Tot_Clms', 'Antpsyct_GE65_Tot_Drug_Cst',
#        'Antpsyct_GE65_Bene_Suprsn_Flag', 'Antpsyct_GE65_Tot_Benes',
#        'Bene_Avg_Age', 'Bene_Age_LT_65_Cnt', 'Bene_Age_65_74_Cnt',
#        'Bene_Age_75_84_Cnt', 'Bene_Age_GT_84_Cnt', 'Bene_Feml_Cnt',
#        'Bene_Male_Cnt', 'Bene_Race_Wht_Cnt', 'Bene_Race_Black_Cnt',
#        'Bene_Race_Api_Cnt', 'Bene_Race_Hspnc_Cnt', 'Bene_Race_Natind_Cnt',
#        'Bene_Race_Othr_Cnt', 'Bene_Dual_Cnt', 'Bene_Ndual_Cnt',
#        'Bene_Avg_Risk_Scre'],
#       dtype='object')

# %%
df = df[['Prscrbr_Crdntls','Prscrbr_State_FIPS','Prscrbr_RUCA','Prscrbr_Type','Opioid_Tot_Clms', 'Opioid_Tot_Drug_Cst',
        'Opioid_Tot_Suply','Opioid_Prscrbr_Rate','Opioid_LA_Tot_Clms','Opioid_LA_Prscrbr_Rate']]
df.head()
# Out:
#   Prscrbr_Crdntls  Prscrbr_State_FIPS  Prscrbr_RUCA             Prscrbr_Type  \
# 0            M.D.                24.0           1.0        Internal Medicine
# 1            M.D.                39.0           1.0           Anesthesiology
# 2             DDS                32.0           2.0                  Dentist
# 3            M.D.                39.0           1.0  Obstetrics & Gynecology
# 4              MD                 8.0           1.0          General Surgery
#
#    Opioid_Tot_Clms  Opioid_Tot_Drug_Cst  Opioid_Tot_Suply  \
# 0             13.0                33.63              67.0
# 1            773.0             32368.09           21196.0
# 2             11.0                65.63              38.0
# 3              NaN                  NaN               NaN
# 4              NaN                  NaN               NaN
#
#    Opioid_Prscrbr_Rate  Opioid_LA_Tot_Clms  Opioid_LA_Prscrbr_Rate
# 0             3.147700                 0.0                0.000000
# 1            50.855263                70.0                9.055627
# 2            10.576923                 0.0                0.000000
# 3                  NaN                 NaN                     NaN
# 4                  NaN                 NaN                     NaN

# %%
df.isna().sum()
# Out:
# Prscrbr_Crdntls           121186
# Prscrbr_State_FIPS          2748
# Prscrbr_RUCA                2748
# Prscrbr_Type                   4
# Opioid_Tot_Clms           345073
# Opioid_Tot_Drug_Cst       345073
# Opioid_Tot_Suply          345073
# Opioid_Prscrbr_Rate       345073
# Opioid_LA_Tot_Clms        430874
# Opioid_LA_Prscrbr_Rate    973903
# dtype: int64

# %%
# too many NA values
df = df.drop(columns='Opioid_LA_Prscrbr_Rate')

# %%
df = df.dropna(subset=['Opioid_Prscrbr_Rate'])

# %%
# drop all rows with NA values, dataset is large and this is a small percentage
df = df.dropna()

# %%
df.shape
# Out:
# (819213, 9)

# %%
df.head(10)
# Out:
#    Prscrbr_Crdntls  Prscrbr_State_FIPS  Prscrbr_RUCA         Prscrbr_Type  \
# 0             M.D.                24.0           1.0    Internal Medicine
# 1             M.D.                39.0           1.0       Anesthesiology
# 2              DDS                32.0           2.0              Dentist
# 5               DO                42.0           1.0    Internal Medicine
# 6       M.D., PH.D                40.0           1.0              Urology
# 7               MD                 6.0           1.0      Cardiac Surgery
# 9             P.A.                48.0           1.0  Physician Assistant
# 10             PHC                35.0           2.0           Pharmacist
# 11            APRN                 6.0           1.0   Nurse Practitioner
# 16            O.D.                48.0           1.0            Optometry
#
#     Opioid_Tot_Clms  Opioid_Tot_Drug_Cst  Opioid_Tot_Suply  \
# 0              13.0                33.63              67.0
# 1             773.0             32368.09           21196.0
# 2              11.0                65.63              38.0
# 5              53.0             11833.04            1012.0
# 6             254.0              1842.13            1345.0
# 7               0.0                 0.00               0.0
# 9               0.0                 0.00               0.0
# 10              0.0                 0.00               0.0
# 11              0.0                 0.00               0.0
# 16              0.0                 0.00               0.0
#
#     Opioid_Prscrbr_Rate  Opioid_LA_Tot_Clms
# 0              3.147700                 0.0
# 1             50.855263                70.0
# 2             10.576923                 0.0
# 5              0.796394                14.0
# 6             13.375461                 0.0
# 7              0.000000                 0.0
# 9              0.000000                 0.0
# 10             0.000000                 0.0
# 11             0.000000                 0.0
# 16             0.000000                 0.0

# %% [markdown]
# ### K-Means Clustering

# %%
# for clustering, drop categorical columns
df_clustering = df.drop(columns = ['Prscrbr_Crdntls','Prscrbr_State_FIPS','Prscrbr_RUCA','Prscrbr_Type'])
df_clustering.head()
# Out:
#    Opioid_Tot_Clms  Opioid_Tot_Drug_Cst  Opioid_Tot_Suply  \
# 0             13.0                33.63              67.0
# 1            773.0             32368.09           21196.0
# 2             11.0                65.63              38.0
# 5             53.0             11833.04            1012.0
# 6            254.0              1842.13            1345.0
#
#    Opioid_Prscrbr_Rate  Opioid_LA_Tot_Clms
# 0             3.147700                 0.0
# 1            50.855263                70.0
# 2            10.576923                 0.0
# 5             0.796394                14.0
# 6            13.375461                 0.0

# %%
# consolidate to 3 features for visualization
df_clustering = df_clustering.drop(columns = ['Opioid_LA_Tot_Clms','Opioid_Tot_Suply'])
df_clustering.head()
# Out:
#    Opioid_Tot_Clms  Opioid_Tot_Drug_Cst  Opioid_Prscrbr_Rate
# 0             13.0                33.63             3.147700
# 1            773.0             32368.09            50.855263
# 2             11.0                65.63            10.576923
# 5             53.0             11833.04             0.796394
# 6            254.0              1842.13            13.375461

# %%
# normalize data 
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()  # standardizes to zero mean and unit variance
df_clustering = pd.DataFrame(scaler.fit_transform(df_clustering), columns=df_clustering.columns)
df_clustering.head()
# Out:
#    Opioid_Tot_Clms  Opioid_Tot_Drug_Cst  Opioid_Prscrbr_Rate
# 0        -0.163440            -0.115952            -0.240732
# 1         2.523028             1.302272             3.089869
# 2        -0.170510            -0.114548             0.277924
# 3        -0.022047             0.401583            -0.404883
# 4         0.688453            -0.036629             0.473298

# %%
# filter out outliers outside of IQR
Q1 = df_clustering.quantile(0.25)
Q3 = df_clustering.quantile(0.75)
IQR = Q3 - Q1
df_clustering = df_clustering[~((df_clustering < (Q1 - 1.5 * IQR)) | (df_clustering > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
df_clustering = df_clustering.sample(frac=0.1, random_state=42)

# %%
import matplotlib.pyplot as plt

# %%
# calculate silhouette scores
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

silhouette_scores = []
k_values = range(2, 10)  # k from 2 to 9

for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    labels = kmeans.fit_predict(df_clustering)
    silhouette_scores.append(silhouette_score(df_clustering, labels))

# Plot Silhouette Scores
plt.figure(figsize=(8, 5))
plt.plot(k_values, silhouette_scores, marker='o', linestyle='--')
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Silhouette Score")
plt.title("Silhouette Method for Optimal k")
plt.show()

# %%
inertias = []
k_values = range(1, 10)

for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(df_clustering)
    inertias.append(kmeans.inertia_)

plt.figure(figsize=(8, 5))
plt.plot(k_values, inertias, marker='o', linestyle='--')
plt.xlabel("Number of Clusters (k)")
plt.ylabel("WCSS")
plt.title("Elbow Method for Optimal k")
plt.show()

# %%
# fit k means on scaled 3d data
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
labels = kmeans.fit_predict(df_clustering)

# Get cluster centers
centroids = kmeans.cluster_centers_

 # Extract the 3 columns for visualization
x, y, z = df_clustering.iloc[:, 0], df_clustering.iloc[:, 1], df_clustering.iloc[:, 2]

# Create 3D scatter plot
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(projection='3d')

# Plot data points
scatter = ax.scatter(x, y, z, c=labels, cmap="viridis", edgecolor='k', s=20, alpha=0.5)

# Plot centroids (black X markers)
ax.scatter(centroids[:, 0], centroids[:, 1], centroids[:, 2], 
               c='red', s=300, marker='X', edgecolors='black', label='Centroids')

    # Labels and Title
ax.set_xlabel('Total Opioid Claims')
ax.set_ylabel('Total Opioid Cost')
ax.set_zlabel('Opioid Prescription Rate')
ax.set_title(f'K-Means Clustering (k=3)')

# Show color bar for cluster labels
plt.colorbar(scatter, label="Cluster Label")

# Show the plot
plt.legend()
plt.show()

# %%
df_clustering.shape
# Out:
# (58487, 3)

# %% [markdown]
# #### Decision Tree

# %%
df['Prscrbr_Crdntls'].value_counts()
# Out:
# Prscrbr_Crdntls
# MD                   206905
# M.D.                 174655
# PA-C                  42362
# DDS                   28597
# DO                    27112
#                       ...
# APNP, DNP                 1
# MD; MSN                   1
# AGACNP (DNP)              1
# FNP-C; PMHNP- BC          1
# D.D.S., MPA, MAED         1
# Name: count, Length: 13881, dtype: int64

# %%
type_counts = df['Prscrbr_Crdntls'].value_counts()
print(type_counts.to_string())
# Out:
# Prscrbr_Crdntls
# MD                      206905
# M.D.                    174655
# PA-C                     42362
# DDS                      28597
# DO                       27112
# D.O.                     24560
# NP                       24034
# O.D.                     17458
# PA                       16296
# FNP                      16066
# APRN                     15203
# D.D.S.                   15089
# DMD                      14846
# OD                       11643
# FNP-C                     9150
# ARNP                      8659
# PHARMD                    8262
# CRNP                      7265
# DPM                       6983
# M.D                       6934
# D.M.D.                    6382
# NP-C                      5908
# FNP-BC                    5190
# CNP                       4279
# RPH                       3914
# P.A.                      3626
# APN                       3205
# N.P.                      2681
# PMHNP                     2458
# D.P.M.                    2373
# PAC                       2344
# D.D.S                     2313
# PMHNP-BC                  2212
# PHARM.D.                  2023
# NURSE PRACTITIONER        1865
# MD, PHD                   1747
# CNM                       1585
# D.O                       1558
# D.M.D                     1520
# MD, MPH                   1435
# M.D., PH.D.               1371
# DNP                       1306
# ANP                       1137
# APNP                      1120
# PHARM D                   1073
# PHYSICIAN ASSISTANT       1045
# MBBS                       993
# APRN, FNP-C                966
# P.A.-C                     960
# APRN-CNP                   923
# RPA-C                      880
# M. D.                      852
# RN                         816
# PHARM.D                    691
# MSN, APRN, FNP-C           651
# AGACNP-BC                  618
# ACNP                       589
# M.D., M.P.H.               541
# MD PHD                     537
# CFNP                       519
# F.N.P.                     504
# N.D.                       501
# ND                         488
# WHNP                       484
# O.D                        477
# APRN, CNP                  416
# PA C                       416
# APRN, FNP-BC               412
# AGACNP                     410
# PHARMACIST                 406
# R.PH.                      405
# P.A.-C.                    390
# MSN, FNP-C                 388
# AGNP                       378
# M.D.,                      376
# DDS, MS                    372
# AGPCNP-BC                  354
# MD, MS                     352
# DDS, MD                    345
# PHARM. D.                  342
# AGNP-C                     330
# ANP-BC                     330
# D.P.M                      327
# WHNP-BC                    316
# DNP, FNP-C                 303
# MPAS, PA-C                 302
# CNS                        293
# DNP, FNP-BC                275
# APRN-BC                    268
# PHARM D.                   263
# PHARMD.                    263
# ACNP-BC                    261
# APRN, PMHNP-BC             257
# A.R.N.P.                   251
# MD, MBA                    249
# MSN, FNP-BC                248
# D.D.S., M.S.               243
# DMD, MD                    236
# MSN, APRN, FNP-BC          235
# M.D,                       229
# APRN, NP-C                 225
# MD.                        218
# MD MPH                     213
# APRN, BC                   205
# M.D., M.S.                 202
# DNP, APRN, FNP-C           201
# AGPCNP                     199
# MSN                        196
# ARNP-C                     194
# NPP                        191
# PHARMD, RPH                191
# PHARM. D                   181
# C.R.N.P.                   176
# M.B.B.S.                   174
# APRN, FNP                  174
# P.A                        173
# MSN, FNP                   170
# RN, FNP                    166
# ANP-C                      165
# RN, CNP                    165
# M.B.B.S                    163
# D.D.S., M.D.               162
# M.D., PHD                  162
# NMD                        157
# DNP, APRN, FNP-BC          157
# RN, NP                     156
# MS, PA-C                   156
# M.D., MPH                  154
# RN, FNP-C                  154
# A.P.R.N.                   151
# APRN FNP-C                 150
# DNP, PMHNP-BC              149
# P.A.C.                     148
# O. D.                      148
# APRN-C                     147
# M D                        146
# N.P                        146
# R.PH                       145
# DMD, MS                    145
# RPAC                       143
# PA-C, ATC                  142
# APN-C                      137
# AG-ACNP                    136
# CRNA                       133
# DDS MS                     133
# MSN, PMHNP-BC              124
# C.N.P.                     123
# DO, MPH                    123
# FNPC                       123
# MSN, APRN, PMHNP-BC        121
# CRNP-PMH                   120
# P.A-C                      120
# MMS, PA-C                  119
# RNP                        116
# MSN, NP-C                  116
# PA-S                       114
# ACNPC-AG                   113
# C.N.M.                     110
# NP-BC                      107
# PHD                        106
# CPNP                       105
# PA-C, MPAS                 105
# DNP, APRN                  103
# MD/PHD                     103
# GNP                        102
# M.D., PH.D                 102
# ARNP-BC                    102
# APRN-NP                    101
# DNP, APRN, PMHNP-BC        100
# M.D. PH.D.                  98
# APRN-FNP                    98
# DDS, MSD                    97
# MD, MSC                     96
# D.M.D., M.S.                96
# A.P.N.                      95
# PNP                         94
# D.M.D., M.D.                93
# RN, MSN, FNP-C              92
# DNP, FNP                    92
# MD PA                       91
# ARNP, FNP-C                 91
# F.N.P                       91
# DENTIST                     91
# D. O.                       90
# MSN, CRNP                   90
# RPA                         89
# M.D., F.A.C.S.              89
# M.D., M.B.A.                88
# RDH                         87
# MEDICAL DOCTOR              86
# MD, DDS                     83
# DDS MD                      83
# MSN, APRN, NP-C             81
# M.D., P.A.                  80
# M.D., M.P.H                 79
# APRN, PMHNP                 78
# A.N.P.                      78
# APRN CNP                    77
# OPTOMETRIST                 77
# DNP, NP-C                   77
# RN, FNP-BC                  77
# DO, MS                      77
# APRN,BC                     76
# BDS                         76
# FNP-C, PMHNP-BC             76
# NPC                         73
# DNP, ARNP                   73
# FNP, PMHNP                  73
# APRN FNP-BC                 71
# MD, FACS                    70
# MD,PHD                      69
# MSN, RN, FNP-BC             68
# RN, NP-C                    68
# ARNP, FNP-BC                68
# R.N.                        68
# MD FACC                     67
# N.M.D.                      67
# RPH.                        67
# MD FACS                     66
# APRN.CNP                    65
# MD, FACC                    64
# MSN, APRN                   63
# MBCHB                       62
# MD, DMD                     61
# DDS,MS                      60
# D.D.S., M.S.D.              60
# APRN BC                     60
# PMH-NP                      60
# PA-C, MPH                   59
# WHCNP                       59
# DNP, PMHNP                  58
# MSN, RN, FNP-C              57
# MBBS, MD                    57
# DDS PC                      57
# AGNP-BC                     57
# RN, PMHNP                   56
# APN, FNP-BC                 55
# C-FNP                       54
# M.D.,PH.D.                  53
# APN-BC                      52
# M.D., F.A.C.C.              52
# RN, MSN, FNP-BC             52
# PH.D.                       51
# DDS, PHD                    50
# M.D., D.D.S.                50
# APN-CNP                     50
# MBBCH                       50
# DMD MD                      50
# MD,MPH                      50
# D.O., M.P.H.                49
# APRN, CNM                   49
# MSN-FNP                     49
# AGPCNP-C                    49
# PA - C                      49
# FNP-BC, PMHNP-BC            48
# D.O,                        48
# ND, LAC                     47
# MHS, PA-C                   47
# MB BCH BAO                  46
# DDS PA                      46
# FPMHNP                      46
# MD PC                       45
# NP, RN                      45
# A-GNP-C                     44
# APRN NP-C                   44
# MPAS                        44
# MSPAS, PA-C                 44
# RN, MSN, FNP                43
# N.P.-C                      43
# P.A.C                       42
# M.S., PA-C                  42
# DNP, CRNP                   42
# APRN FNP                    42
# NURSE PRACTIONER            42
# OD, MS                      41
# APRN,CNP                    41
# D.D.S.,M.S.                 41
# CNM, WHNP                   41
# APRN, DNP                   40
# BS                          40
# MSN, RN, PMHNP-BC           40
# DNP-FNP                     40
# CRNP, FNP-C                 39
# MD/MPH                      39
# D. D. S.                    39
# FAMILY NURSE PRACTIT        39
# RNCS                        39
# RN, APRN                    39
# RN, MSN, NP-C               38
# MSN FNP-C                   38
# M.D./PH.D.                  38
# A.R.N.P                     38
# STUDENT                     38
# APRN-FNP-C                  38
# DMD, MSD                    37
# MD, FACP                    37
# N.D., L.AC.                 36
# MS                          36
# APRN-CNS                    36
# O.D., M.S.                  36
# M.D., D.M.D.                35
# DMD MS                      35
# ACNS-BC                     35
# MSN, NP                     35
# MSN APRN FNP-C              35
# CNM, WHNP-BC                35
# MSN FNP                     34
# DO, MBA                     34
# C.F.N.P.                    34
# D.O., M.S.                  34
# MD, PH.D.                   34
# DDS,MD                      33
# MD FACP                     33
# DMD, MPH                    33
# PMHNP-BC, FNP-C             33
# DDS, MPH                    33
# D.D.S., P.C.                33
# M.D. PHD                    33
# APRN, AGACNP-BC             33
# PMHCNS-BC                   33
# ARNP, DNP                   33
# DNP, APRN, NP-C             33
# RN, APN                     33
# M.D., J.D.                  32
# DDS.                        32
# FNP BC                      32
# MD MS                       32
# APN, FNP                    32
# RN, PMHNP-BC                32
# A-GNP                       32
# ARNP, PMHNP-BC              31
# M.D., PHD.                  31
# R.N., N.P.                  31
# ARNP, NP-C                  31
# DNP, AGNP-C                 31
# GNP-BC                      31
# MSN, WHNP-BC                31
# PA-C, MMS                   31
# MPA, PA-C                   31
# DNP, AGACNP-BC              31
# REGISTERED NURSE            31
# DNP, ARNP, FNP-C            31
# DDS MSD                     30
# MD, MA                      30
# MSN, AGACNP-BC              30
# M.D., M.SC.                 30
# M.D., M.A.                  30
# DDS, PC                     30
# PHARMD, BCPS                30
# MS, FNP-BC                  30
# FNP- BC                     29
# O D                         29
# MD, MBBS                    29
# RN, MSN                     29
# FNP, RN                     29
# APN, CNP                    29
# APRN, CNS                   29
# P.A. - C                    29
# RN, ANP                     28
# M.D., P.C.                  28
# APRN, AGNP-C                28
# APN, FNP-C                  28
# MSN, ARNP                   28
# CNM, ARNP                   28
# MD, MSPH                    28
# MSN, PMHNP                  28
# MD DDS                      28
# P. A.                       28
# MD, MHS                     28
# OD, FAAO                    28
# DO, PHD                     27
# PH.D., M.D.                 27
# PA-C, MS                    27
# FNP-BC, NP-C                27
# PMHNP-BC, FNP-BC            27
# MSN, APRN, BC               27
# M.D., MBA                   27
# CNM, NP                     27
# RN, BSN                     27
# RN NP                       27
# O.D., F.A.A.O.              26
# RN CNP                      26
# MD, JD                      26
# MSN, RN, NP-C               26
# MSN, APRN, AGACNP-BC        26
# MSN, APN                    26
# M.D., FACS                  26
# PHARM.D., RPH               26
# MSN, APRN, AGNP-C           26
# DDS, PA                     26
# APRN, RN                    26
# MPH, PA-C                   26
# APRN PMHNP-BC               26
# APRN-RX                     26
# MPH                         26
# MD, PHARMD                  26
# FNP - C                     25
# PD                          25
# F.N.P.-C                    25
# RN/NP                       25
# MSN FNP-BC                  25
# ATC, PA-C                   25
# AG-ACNP-BC                  25
# ARPN                        25
# DOCTOR OF PHARMACY          25
# MSN, ARNP, FNP-BC           25
# MD, MHA                     25
# RN FNP                      25
# RN, ACNP                    25
# RN, MSN, PMHNP-BC           25
# DPH                         25
# PHARMD, MBA                 24
# FNP-C, APRN                 24
# MEDICAL STUDENT             24
# DNP, RN, FNP-BC             24
# PCNS                        24
# APRN, WHNP-BC               24
# RPA C                       24
# CPNP-PC                     24
# PMHNP, FNP                  24
# PHD, MD                     24
# MSN, CNM                    24
# R-PAC                       24
# M.D., M.B.A                 24
# MSN, CNP                    23
# M.D, M.P.H                  23
# APRN,FNP-C                  23
# FNP, BC                     23
# RPH, PHARMD                 23
# DDS, FAGD                   23
# MSN, ARNP, FNP-C            23
# MSN, APRN-BC                23
# PA-C, RD                    23
# DNP, ARNP, FNP-BC           23
# RN, CNM                     23
# M.D..                       23
# RN, CRNP                    23
# M,D.                        23
# DR                          23
# DNP, FNP-C, PMHNP-BC        22
# D.C.                        22
# M.D.,F.A.C.S.               22
# D.M.D., M.S.D.              22
# DOCTOR OF OPTOMETRY         22
# M,D,                        22
# C.R.N.P                     22
# DNP, ARNP, PMHNP-BC         22
# C-NP                        22
# M.D, PH.D.                  22
# MD, MPH, MS                 22
# PHARM-D                     22
# MD, PA                      22
# D.D.S., P.A.                22
# DR.                         22
# ARNP, CNM                   21
# DDS PHD                     21
# FNP C                       21
# MD, PH.D                    21
# CRNP, FNP-BC                21
# M.D, MPH                    21
# MSN, APRN, FNP              21
# D.O., MPH                   21
# M.B., B.S.                  21
# N. P.                       21
# B.S.                        21
# PH                          21
# F-NP                        21
# MSN, RN                     20
# APN, NP-C                   20
# D.O., PH.D.                 20
# MSN, ANP-BC                 20
# RN, CNS                     20
# MSN, CRNP, FNP-C            20
# M.D., PH. D.                20
# APRN, MSN, FNP-C            20
# MSN, ACNP-BC                20
# CNM, FNP                    20
# APRN-PMHNP                  20
# DNP, APRN, CNP              20
# APNC                        20
# O.D,                        20
# MD-PHD                      20
# OD PA                       20
# DC                          19
# PSY.D.                      19
# FPMHNP-BC                   19
# M.D., F.A.C.P.              19
# FNP-C, RN                   19
# CRNP-FAMILY                 19
# D.M.D., P.A.                19
# MSN, AGNP-C                 19
# M.D.,M.P.H.                 19
# DNP, PMHNP-BC, FNP-C        19
# MS, MD                      19
# D.D.S, M.S.                 18
# RN, MSN, ACNP-BC            18
# MD MBA                      18
# PHYSICIANS ASSISTANT        18
# MD FACOG                    18
# MS, FNP-C                   18
# MBBS, MPH                   18
# RN FNP-C                    18
# AGCNS-BC                    18
# M.D., M.H.S.                18
# D.N.P.                      18
# APRN, NP                    18
# MPA-C                       18
# MSN, RN, AGACNP-BC          18
# ARNP-FNP                    18
# M.B.,B.S.                   17
# C.N.M                       17
# LCSW                        17
# BDS, MS                     17
# MD, FACOG                   17
# PMHNP-BC, RN                17
# ACAGNP                      17
# MA                          17
# MD, PHD, MPH                17
# M.S.                        17
# MS, APRN, FNP-C             17
# D.M.D., P.C.                17
# LNP                         17
# MSN,FNP-BC                  17
# FNP - BC                    17
# MSN, APN, FNP-BC            17
# DNP, AGPCNP-BC              17
# APRN-CNP, PMHNP-BC          17
# MD,                         17
# P.D.                        17
# CRNP-F                      17
# D.D.S.,M.D.                 17
# ARNP, FNP                   16
# M.D., F.A.C.O.G.            16
# ANPC                        16
# APN,C                       16
# M.D. M.P.H.                 16
# DO MPH                      16
# PHMNP                       16
# MB, BCH, BAO                16
# APRN, MSN, PMHNP-BC         16
# RN, MSN, NP                 16
# M.D., FACC                  16
# ARNP, PMHNP                 16
# APN, PMHNP-BC               16
# MSN, AGPCNP-BC              16
# D O                         16
# APRN-CNM                    16
# CNP, RN                     16
# MD, DO                      16
# CNP, PMHNP-BC               16
# MD INC                      16
# B.PHARM                     16
# APRN, AGPCNP-BC             16
# DNP, CNM                    16
# MS PA-C                     16
# PMHNP-BC, APRN              16
# M.D.,P.A.                   16
# ARNP, RN                    16
# RN, ARNP                    16
# DNP FNP-BC                  15
# M.D. PH.D                   15
# DNP, APN                    15
# AGAC-NP                     15
# W.H.N.P.                    15
# R. PH.                      15
# CANP                        15
# DPM, MS                     15
# PA-C, MHS                   15
# NP, CNS                     15
# PA-C, M.S.                  15
# M.D.,PHD                    15
# ARNP FNP-BC                 15
# R.N., F.N.P.                15
# DNP-PMHNP                   15
# NP-P                        15
# DNP, WHNP-BC                15
# A.P.N                       15
# ACNP-C                      15
# M.D.,F.A.C.C.               15
# FNP-BC, APRN                15
# DNP FNP-C                   15
# ARNP-CNP                    15
# MSPA, PA-C                  15
# DDS, MS, PHD                15
# M.D. P.A.                   15
# FNP-BC, RN                  15
# PA- C                       14
# C.N.P                       14
# DMD MSD                     14
# O,D.                        14
# PT                          14
# M.D. FACC                   14
# M. D                        14
# DPM, MPH                    14
# PHARM D, RPH                14
# MD,MBA                      14
# RN MSN FNP                  14
# CRNP, FNP                   14
# MS, FNP                     14
# D.D.S., F.A.G.D.            14
# OD PC                       14
# APRN/CNP                    14
# PSYCHIATRIC NP              14
# RN, CFNP                    14
# CNM, MSN                    14
# DNP, APRN, AGACNP-BC        14
# MSN, ANP                    14
# PA-C, MMSC                  14
# M..D.                       14
# MPA                         14
# DC, PA-C                    14
# PA, ATC                     14
# LPN                         14
# FNP, APRN                   14
# FNP, NP-C                   14
# N.P.P.                      14
# MHNP                        14
# DNP, RN, PMHNP-BC           14
# M.D., MSC                   14
# PMHNP-BC, MSN               13
# R.P.A.-C                    13
# M.D, PH.D                   13
# MD, MBA, MPH                13
# MSPA-C                      13
# DNP,FNP-C                   13
# DNP, CNP                    13
# MD  PHD                     13
# R.P.A.                      13
# PMHNP - BC                  13
# APRN PMHNP                  13
# CRNP-BC                     13
# DNP, CRNP, FNP-BC           13
# N.M.D                       13
# M.D., FACP                  13
# DMD PA                      13
# DMD,MS                      13
# DPM, FACFAS                 13
# DMD PC                      13
# PMHNP, RN                   13
# PSYD                        13
# MSN-FNP-C                   13
# PMHCNS                      13
# MPAP, PA-C                  13
# RNFA                        13
# DDS, MDS                    13
# BA                          13
# PHARM.D., BCPS              13
# RNNP                        13
# DNP, NP                     13
# DMSC, PA-C                  12
# D.M.D, M.D.                 12
# A.P.R.N                     12
# D.M.D.,M.S.                 12
# M.D. MPH                    12
# ARNP, BC                    12
# RN,FNP                      12
# DDS MPH                     12
# MD DMD                      12
# PH.D., M.P.                 12
# PA-C, MSPAS                 12
# D.D.S,                      12
# MSN,APRN,FNP-C              12
# MD, FAAP                    12
# D D S                       12
# M.D., D.O.                  12
# APRN- CNP                   12
# CM                          12
# M.S.N.                      12
# MSN, APN, FNP-C             12
# NURSE PRACTITONER           12
# MN, ARNP                    12
# MPAS PA-C                   12
# FNP, CNM                    12
# FNP, MSN                    12
# C.N.S.                      12
# APN/CNP                     12
# M.D., PHARM.D.              12
# PA.C                        12
# APRN, BC, FNP               12
# R PH                        12
# MS PAC                      12
# P.A. -C                     12
# CNM, APRN                   12
# MSN, APRN, WHNP-BC          12
# DPM PC                      12
# GNP-C                       12
# PHD, APRN                   12
# APRN-BC, FNP                12
# M.D, PHD                    12
# M.D. PC                     12
# P.A.- C                     12
# M.D.,PH.D                   12
# D. M. D.                    12
# D.D.S.,P.C.                 12
# PHARMD, BCACP               12
# PHARMD, CPP                 12
# RN,NP                       11
# MCMSC, PA-C                 11
# DO, MA                      11
# MD, MSCR                    11
# RPH, PHARM D                11
# M.D., F.A.A.P.              11
# M.S., M.D.                  11
# MD FCCP                     11
# BSPHARM                     11
# BDS, MSD                    11
# A.C.N.P.                    11
# M.D., FACEP                 11
# M.D., M.S                   11
# RN, MSN, CNP                11
# NP MSN                      11
# MD/MBA                      11
# RN,MSN,FNP-C                11
# DNP, APNP                   11
# MD,MS                       11
# M.D.,P.C.                   11
# PHARM.D, RPH                11
# OD, MPH                     11
# AGPC-NP                     11
# MS, NP-C                    11
# MSN, FNP-C, PMHNP-BC        11
# OD.                         11
# DNP, RN                     11
# PMHNP, BC                   11
# APN FNP-BC                  11
# BC-FNP                      11
# CNM, FNP-BC                 11
# RN, CPNP                    11
# RNC                         11
# D.PH.                       11
# MSN, APRN, AGCNS-BC         11
# RN, ACNP-BC                 11
# PA-C.                       11
# MD JD                       11
# M.D., F.C.C.P.              11
# CPNP-AC                     11
# D.D.S., PH.D.               11
# MSN, APRN, AGPCNP-BC        11
# MSN,FNP                     11
# ACNP-AG                     11
# APRN- FNP                   11
# MMSC, PA-C                  11
# RN-FNP                      10
# RN, APN-C                   10
# DNP, APN, PMHNP-BC          10
# APRN,FNP                    10
# N.D                         10
# PMHNP-BC, DNP               10
# NP-C, RN                    10
# MD, MS, MPH                 10
# NP, CNM                     10
# M.D.,M.S.                   10
# M.D./M.P.H.                 10
# DMD, MDS                    10
# D.O., M.B.A.                10
# F.N.P.-C.                   10
# NP, APRN                    10
# MD, FCCP                    10
# MSN APRN FNP-BC             10
# RNC WHNP                    10
# APRN, MSN, FNP-BC           10
# DMD, PC                     10
# O.D., M.P.H.                10
# DMD, PA                     10
# MSN, APRN-CNP               10
# MBBS, PHD                   10
# MSN NP                      10
# PMHNP-C                     10
# MD, DC                      10
# PHAMD                       10
# DDS,PA                      10
# APRN CNM                    10
# DNP, APRN, PMHNP            10
# DNP-PMHNP-BC                10
# M.D., D.D.S                 10
# MD,FACC                     10
# APRN, AGACNP                10
# M.D., F.A.C.S               10
# PA -C                       10
# DDS PLLC                    10
# PHARMD, PHC                 10
# APN-NP                      10
# LPC                         10
# DNP PMHNP                   10
# M.M.S., PA-C                10
# MSN, APRN, PMHNP            10
# FNP, DNP                    10
# RN, WHNP-BC                 10
# PMHNP BC                    10
# ARNP FNP-C                  10
# MSN,FNP-C                   10
# APRN,FNP-BC                 10
# MS, DO                      10
# APMHNP-BC                   10
# RN, WHNP                    10
# FNPBC                       10
# NP, MSN                     10
# DNP FNP                     10
# MSN, ARNP-BC                10
# RD, PA-C                    10
# MD MSC                      10
# MS,PA-C                     10
# C.F.N.P                     10
# M.S. PA-C                    9
# APN, NP                      9
# D.O..                        9
# MBBS PHD                     9
# M.D./PH.D                    9
# DMD,MD                       9
# MD FAAP                      9
# PHD, PMHNP-BC                9
# D. D. S                      9
# D.D.S, P.A.                  9
# M.D., P.H.D.                 9
# APN, CNM                     9
# PHD, NP                      9
# FNP-C, AGACNP-BC             9
# RN, BSN, MSN, FNP-C          9
# ARNP, MSN                    9
# BS PHARMACY                  9
# DNP, APNP, FNP-BC            9
# MSN, RN, AGPCNP-BC           9
# FAMILY NP                    9
# FNP-C, MSN                   9
# DNP, FNP, PMHNP              9
# MSN CRNP                     9
# DNP, ACNP-BC                 9
# DNP, RN, FNP-C               9
# ARNPC                        9
# OD OPTOMETRIST               9
# D.M.D,                       9
# DC, FNP                      9
# D,D,S,                       9
# R.N.P.                       9
# NNP                          9
# DDS,PC                       9
# DMD, PHD                     9
# CRNP, PMHNP-BC               9
# RN, MS, FNP-C                9
# BSN, RN                      9
# DNP, APRN-BC                 9
# ATC                          9
# APRN-CNP, FNP-C              9
# PMHNP, APRN                  9
# DMD, FAGD                    9
# MSPA                         9
# APNP, FNP-BC                 9
# PHARM.D., R.PH.              9
# RN, ACNS-BC                  9
# OD, PHD                      9
# M.D., M.H.A.                 9
# FNP- C                       9
# APRN-FNP-BC                  9
# D.D.S, M.D.                  9
# RNC, WHNP                    9
# APMHNP                       9
# MD, MBE                      9
# ADULT NP                     9
# DMD, MMSC                    9
# APN, C                       9
# PA-C, PHD                    9
# D.C., PA-C                   9
# MSN/FNP                      9
# BDS, DMD                     9
# ENP                          9
# MS, RN, FNP-BC               9
# MSN, RN, FNP                 9
# GENERAL DENTIST              9
# B.D.S.                       9
# D.D.S., M.P.H.               9
# DNP, FNP-BC, RN              9
# M.D., M.S.P.H.               9
# RN, ANP-BC                   9
# MDPA                         9
# MSN, APN, PMHNP-BC           9
# MSPAS                        9
# O.D., PH.D.                  9
# M.B.B.CH                     9
# MB,BS                        9
# MD, FRCSC                    9
# DNP, APRN, AGPCNP-BC         9
# MBBS, MS                     9
# MD. PHD                      9
# MB CHB                       9
# RD                           9
# PMH NP                       9
# FNP-C, FNP-BC                9
# CRNP, RN                     9
# FNP-BC, MSN                  9
# CRNP, MSN                    8
# APRN, CNP, PMHNP-BC          8
# PHD, MP                      8
# MSN, FNP, PMHNP              8
# DDS, MBA                     8
# RNP-C                        8
# D.M.D., F.A.G.D.             8
# ANP/GNP                      8
# MSN CNP                      8
# DNP PMHNP-BC                 8
# PHD, PA-C                    8
# P A                          8
# DMD MAGD                     8
# D                            8
# RN, MS, FNP                  8
# RN, MSN, ACNP                8
# G.N.P.                       8
# MSN, CRNP, FNP-BC            8
# APRN BC FNP                  8
# DDS, MAGD                    8
# ARNP C                       8
# B.D.S                        8
# O.D., P.A.                   8
# FNP-BC, FNP-C                8
# NP-C, PMHNP-BC               8
# R.N                          8
# NP C                         8
# MSN, APN-C                   8
# ACNS                         8
# PA-C MPAS                    8
# CNM, MS                      8
# RP                           8
# DNP, APRN, AGNP-C            8
# APRN - CNP                   8
# MS, APRN, FNP-BC             8
# ADULT NURSE PRACTITI         8
# MS, RPA-C                    8
# NP-C, FNP-BC                 8
# MSN, FPMHNP                  8
# BPHARM                       8
# PHYSICAN ASSISTANT           8
# ANP, RN                      8
# MS, RN, FNP-C                8
# PHYSICIAN                    8
# RN, MSN, AGACNP-BC           8
# CRNP-C                       8
# MSN, ANP-C                   8
# BSPH                         8
# DNP, CNP, PMHNP-BC           8
# R.N., M.S.N., F.N.P.         8
# RN, MSN, CFNP                8
# M                            8
# PMHNP, DNP                   8
# BDS, MDS                     8
# MD, FAAFP                    8
# APRN-RNP                     8
# MSN, RN, APRN, FNP-C         8
# M.B.CH.B.                    8
# C-PA                         8
# MSN RN FNP-BC                8
# BSN                          8
# MSN, APRN, A-GNP-C           8
# A.N.P                        8
# D.O.,                        8
# NPF                          8
# D,O.                         8
# FNP-BC, APNP                 8
# APRN, DNP, FNP-C             8
# MIDWIFE                      8
# RN, MSN, ANP-BC              8
# MSN, APRN, CNP               8
# DMD LLC                      8
# NP-C, FNP                    8
# M.D., MBBS                   8
# N.P.-C.                      8
# DMD,MSD                      8
# M.D. PHD.                    8
# MD, MAS                      8
# PHD MD                       8
# FNP MSN                      8
# AANP                         8
# N.D., L.AC                   8
# M.S., D.D.S.                 8
# APN, BC                      8
# DNP, APRN-CNP                8
# M.B.CH.B                     8
# PC                           8
# R.N., C.N.P.                 8
# PHD, APRN, BC                8
# DO PHD                       8
# MBBS,MD                      8
# M.D.,MPH                     8
# APRN-PMHNP-BC                8
# D,D.S.                       8
# PMHNP- BC                    8
# D.D.S.,P.A.                  8
# APRN, PHD                    8
# RN, ANP-C                    8
# DNP-APRN                     8
# RN, BSN, FNP-C               8
# CNP, FNP                     7
# DO, MHA                      7
# MS, CRNP                     7
# CRNP-FNP                     7
# MS, APRN                     7
# MSN APRN                     7
# PHC                          7
# APN, RN                      7
# MSN APRN BC                  7
# MMS PA-C                     7
# APN, PMHNP                   7
# AGACNP-BC, FNP-BC            7
# MS, APRN, PMHNP-BC           7
# MD  PA                       7
# DPM, PA                      7
# M.D., PA                     7
# APRN, FNP, BC                7
# RN MSN                       7
# NP-C, APRN                   7
# MD, MPH, MBA                 7
# APRN, ANP-BC                 7
# MB, BCH                      7
# APRN,NP-C                    7
# PA-C, MSPAS, MPH             7
# DNP APRN                     7
# RN,FNP-BC                    7
# CNP-BC                       7
# DNP-FNP-C                    7
# OD, PA                       7
# ANP, GNP                     7
# M.B.B.S., M.D.               7
# MD, PHD.                     7
# RN, BSN, PMHNP-BC            7
# MSN, AGNP                    7
# P.M.H.N.P.                   7
# D.C., FNP-C                  7
# RNCNP                        7
# M.D. M.S.                    7
# DDS INC                      7
# O,D,                         7
# MSN,NP-C                     7
# PHARM.D,                     7
# MD, FACEP                    7
# MD, PC                       7
# R.D.H.                       7
# M.D.,D.D.S.                  7
# DDS PS                       7
# DDS MAGD                     7
# ARNP NP-C                    7
# D.D.S., MD                   7
# D.O., M.P.H                  7
# MD, MSCI                     7
# CRNM                         7
# APRN-CNP, FNP-BC             7
# RN, AGACNP-BC                7
# PHD, CRNP                    7
# D.M.D, M.S.                  7
# RN MSN FNP-C                 7
# DNP, APRN, FNP               7
# MSN, PMHNP-BC, RN            7
# PSYCH NP                     7
# BMBS                         7
# CNP, APRN                    7
# M.B.,B.S                     7
# PA-C, ATC, CSCS              7
# M.D. FACS                    7
# N.D., LAC                    7
# PHD, ARNP                    7
# BS PHARM                     7
# DPM PA                       7
# MD FACE                      7
# PA STUDENT                   7
# D.O. MPH                     7
# MSN, ARNP, NP-C              7
# APRNBC                       7
# MS, AGACNP-BC                7
# DNP, FNP-BC, NP-C            7
# RN, MSN, ANP                 7
# PHARMD, MD                   7
# REGISTERED PHARMACIS         7
# DMD, MAGD                    7
# DDM                          7
# MSN, FNP-C, APRN             7
# DNP, PMHNP, FNP              7
# CRNP-A                       7
# MSM, PA-C                    7
# APRN,PMHNP-BC                7
# MSN, RN, WHNP-BC             7
# MSN, APRN-CNP, FNP-C         7
# FNP -C                       7
# RN FNP-BC                    7
# PMNHP                        7
# MD,PH.D                      7
# APNP, PMHNP-BC               7
# RN, APRN, FNP-C              7
# D.M.D., MD                   7
# AGACNP-C                     7
# DDS,MSD                      7
# DO, MPH, MS                  7
# M.C.                         7
# RN, APNP                     7
# APN, CNS                     7
# MD, MMSC                     7
# APRN, FNP, PMHNP             7
# R.P.A.C.                     7
# MSN, AGACNP                  7
# APRN - FNP                   6
# PHD, APRN, PMHNP-BC          6
# DNP-BC                       6
# APNP, FNP-C                  6
# ANCC                         6
# MSN, RN, PMHNP               6
# MD, MPP                      6
# DDS DENTIST                  6
# CNM, RN                      6
# WHNP-BC, FNP-C               6
# PA.                          6
# DNP, MSN, FNP-C              6
# D.D.S.,M.A.G.D.              6
# M.D., FAAD                   6
# MSN, APNP                    6
# MD FACC FSCAI                6
# RNFNP                        6
# M.D., D.C.                   6
# AGACNP-BC, DNP               6
# RN, APN, C                   6
# FNP -BC                      6
# FNP-BC, MSN, RN              6
# DNP ARNP                     6
# MS-FNP                       6
# DC, NP-C                     6
# DNP, AGACNP                  6
# MD, DPM                      6
# APRN FNP BC                  6
# CNS-BC                       6
# MSN, RN, APN-C               6
# D.M.D, M.S                   6
# M.D., B.S.                   6
# DDS, MMSC                    6
# RN, MSN, PMHNP               6
# M.B.B.S, MD                  6
# NMW                          6
# DMD PHD                      6
# F.N.P.-B.C.                  6
# FNP,BC                       6
# MS FNP                       6
# D.M.D., M.A.G.D.             6
# M.D, M.P.H.                  6
# ANP-BC, PMHNP-BC             6
# MD, MPHS                     6
# RN,FNP-C                     6
# DNP, APN, FNP-BC             6
# ANRP                         6
# AG-ACNP, BC                  6
# MS, DMD                      6
# RN ANP                       6
# M.D., O.D.                   6
# PA-C, LAT, ATC               6
# N.P-C                        6
# PHARMD RPH                   6
# D.D.S, M.S                   6
# D,D,S                        6
# DNP/FNP                      6
# D P M                        6
# AGACNP-BC, RN                6
# APRN-FAMILY                  6
# CNFP                         6
# MD, MRCP                     6
# M.D., M.P.P.                 6
# PHARM, D                     6
# DDS MS PHD                   6
# AGPCNP-BC, RN                6
# FNP-C, MSN, RN               6
# MD SC                        6
# DNP, FNP-BC, APRN            6
# CRNP FNP-BC                  6
# RN, MSN, APRN                6
# M.D., P.H.D                  6
# RN, AGPCNP-BC                6
# M.S., D.O.                   6
# F.N.P.-BC                    6
# MSN, APNP, FNP-C             6
# APRN, A-GNP-C                6
# FNP-BC, AGACNP-BC            6
# M.D.,F.C.C.P.                6
# CERTIFIED NURSE MIDW         6
# APRN, FNP, PMHNP-BC          6
# RN, BSN, FNP-BC              6
# CNM, DNP                     6
# RN, BC, FNP                  6
# ANP-BC, GNP-BC               6
# MPH, MD                      6
# RN, MSN, WHNP-BC             6
# NP, PHD                      6
# LMHC                         6
# RN NP-C                      6
# MS, NP                       6
# DNP, CRNP, FNP-C             6
# FNP-BC, ACNP-BC              6
# PHARMD., RPH                 6
# M.D, FACC                    6
# M.P.A.S., PA-C               6
# CRNP, DNP                    6
# PHARMD, MPH                  6
# PHMNP-BC                     6
# D.D.S.,PA                    6
# P.N.P.                       6
# OD FAAO                      6
# FAMILY PRACTICE              6
# M.D., FACOG                  6
# APNP-BC                      6
# PSYCHIATRIST                 6
# PTA                          6
# DNP,  APRN                   6
# O.D. PC                      6
# PMHNP, MSN, RN               6
# APRN-NPC                     6
# DDS, M.D.                    6
# DMD, DDS                     6
# CNM, FNP-C                   6
# R.N., ANP                    6
# FNP-C, RNFA                  6
# PA-C, RDN                    6
# DO.                          6
# D.D.S., M.D.S.               6
# MD, FAAD                     6
# PHARM D., RPH                6
# MSN, ACNP                    6
# PHD, FNP                     6
# MSN, ARNP, PMHNP-BC          6
# RN CNS                       6
# ARNP BC                      6
# AGPNP                        6
# DNP, FNP, PMHNP-BC           6
# M.D. PA                      6
# M.D., FAAFP                  6
# PH.D                         6
# DNP, PMHNP-BC, RN            6
# RN CPNP                      5
# MS, RN, PMHNP-BC             5
# CNP-FNP                      5
# M.D. INC                     5
# D.D.S. M.D.                  5
# DCNP                         5
# MS, APRN, BC                 5
# MD, DDS, FACS                5
# FNP-C, MPH                   5
# APRN-FPA                     5
# MD MHS                       5
# MD, MPHIL                    5
# MW                           5
# FNP-C, ARNP                  5
# MSN PMHNP-BC                 5
# ARNP-FNP-C                   5
# FNP-BC, PMHNP                5
# MD STUDENT                   5
# MSN, RN, ACNP-BC             5
# DNP,PMHNP-BC                 5
# DNP-C                        5
# M.D., M.P.A.                 5
# FMHNP                        5
# D.M.D. P.A.                  5
# MD., MPH                     5
# D.O, MPH                     5
# RN, APRN-BC                  5
# M.D.,FACOG                   5
# DO, MD                       5
# PC-C                         5
# M.D.,PHD.                    5
# D.C., NP-C                   5
# MD,DDS                       5
# DDS, MSC                     5
# PHYSICIAN ASSITANT           5
# PA-C, D.C.                   5
# D.D.S, P.A                   5
# FNP-C, CNM                   5
# MDPHD                        5
# RN APNC                      5
# M.S., P.A.-C                 5
# ME                           5
# FNP APRN                     5
# CNP, PMHNP                   5
# RN,MSN,FNP-BC                5
# P-MHNP                       5
# APRN, AGCNS-BC               5
# DDS, PLLC                    5
# PA-C, DC                     5
# RN CFNP                      5
# MD OBGYN                     5
# M.D., INC.                   5
# DMD MDS                      5
# APRN, FNP-C,PMHNP-BC         5
# RN, BSN, MSN                 5
# PA-C, LCSW                   5
# D. P. M.                     5
# M.D. & PH.D.                 5
# RN,CNP                       5
# MSHS, PA-C                   5
# FNP-C, ENP-C                 5
# MD, MSC, PHD                 5
# FNP-C PMHNP-BC               5
# M.D., FAAP                   5
# MD, DPHIL                    5
# RN,APN,C                     5
# M.D. P.C.                    5
# DO, MHSA                     5
# MD, MSW                      5
# MN                           5
# APRN, ACNP                   5
# AHCNS                        5
# FNP-C, PMHNP                 5
# APN-CNS                      5
# DNP,FNP                      5
# M.D. M.P.H                   5
# DNP, APRN, A-GNP-C           5
# DDS, DMSC                    5
# DO, MSC                      5
# RN, APRN, FNP-BC             5
# ACAGNP-BC                    5
# MSN, APRN, AGPCNP-C          5
# DO, ATC                      5
# APRN,MSN,FNP-C               5
# NP, DNP                      5
# PMHNP-DNP                    5
# DDS FAGD                     5
# M.D. F.A.C.S.                5
# MD MBBS                      5
# MBBS/MD                      5
# D.O., D.C.                   5
# RN ARNP                      5
# PHYSICIAN/MD                 5
# NP-PP                        5
# ANP, PMHNP                   5
# M.B.B.CH.                    5
# MHS PA-C                     5
# RNC, NP                      5
# MD, MSC, FRCPC               5
# DNP-FNP-BC                   5
# DO, MBS                      5
# O.D., P.C.                   5
# DNP, AGNP                    5
# D.C., N.D.                   5
# DNP, FNP-C, APRN             5
# RN, AGNP-C                   5
# RNC,WHNP                     5
# F.N.P-C                      5
# DO MS                        5
# MSN, CNP, PMHNP-BC           5
# MSN ARNP                     5
# DDS, BS                      5
# D.M.D., M.B.A.               5
# APRN, FNP-BC, NP-C           5
# PA, MPH                      5
# ANP, FNP                     5
# DNP APRN FNP-C               5
# PA-C, RD, LD                 5
# R.P.H.                       5
# FNP-C APRN                   5
# NURSE PRACTITIONER-C         5
# PMHNP-BC, MSN, RN            5
# M.D.P.C.                     5
# OD MS                        5
# M.B.                         5
# INTERNAL MEDICINE            5
# D.D.S., PA                   5
# FNP, ARNP                    5
# PHARMD, BCACP, CPP           5
# A.P.N.P.                     5
# PA-C, DMSC                   5
# D.M.D.,P.A.                  5
# RN APRN                      5
# ACNP, FNP                    5
# NP NURSE PRACTITIONE         5
# DDS MDS                      5
# AGACNP-BC, FNP-C             5
# MSN,APRN,FNP-BC              5
# MD, FACE                     5
# PA-C, L.AC.                  5
# D.O., PHD                    5
# RN,CS                        5
# APRN,BC,FNP                  5
# MD, MPH, FAAFP               5
# APN FNP-C                    5
# MD, MSE                      5
# D.D.S, M.S.D.                5
# MPAS PAC                     5
# M.D., DDS                    5
# DMD, MHS                     5
# D.M.D.,M.D.                  5
# NP-F                         5
# PHD APRN                     5
# APRN NP                      5
# APRN,CNM                     5
# OGNP                         5
# MSN, APRN, ACNP-BC           5
# AGACNP, FNP                  5
# DMD.                         5
# ADVANCED PRACTICE NU         5
# APRN, WHNP                   5
# APRN, DNP, FNP-BC            5
# ARNP FNP                     5
# M,D                          5
# MNSC, APRN, PMHNP-BC         5
# M.D., FRCSC                  5
# MS, ARNP                     5
# RN APN                       5
# DNP, ANP-C                   5
# F. N. P.                     5
# DNP,FNP-BC                   5
# FNP, APN                     5
# WHNP, CNM                    5
# MD CM                        5
# M.A.                         5
# D. O                         5
# MD,FACP                      5
# PHARM.D., PH.D.              5
# O.D, M.S                     5
# APN, MSN                     5
# APRN-CNP, PMHNP              5
# PMHNP, MSN                   5
# MD, MPH&TM                   5
# MS, CNM                      5
# CNP, FNP-C                   5
# APN CNP                      5
# ND, LAC.                     5
# FNP-BC, DNP                  5
# APRN CNS                     5
# FNP/PMHNP                    5
# MS, ANP-BC                   5
# M.D.P.A.                     5
# DNP, ARNP-C                  5
# MD PSYCHIATRIST              5
# FNP-C, D.C.                  5
# MB BCH                       4
# OD, MS, FAAO                 4
# M.D., PH.D., M.P.H.          4
# MD PHD MPH                   4
# APRN-FNPC                    4
# APN/FNP                      4
# BS, PHARMD                   4
# DDS, DMD                     4
# M.D., M.ED.                  4
# APN,FNP                      4
# ACCNS-AG                     4
# DNP, PMHNP-BC,FNP-BC         4
# PHD, M.D.                    4
# DNP, AGPCNP                  4
# RN, MSN, CPNP                4
# M.D., M.P.H., M.S.           4
# P.A.,                        4
# CNS, CNP                     4
# PMHNP-BC, LMHC               4
# WHNP-C                       4
# M.D.,M.B.A.                  4
# ND, LMP                      4
# APP                          4
# D.D.S., M.A.G.D.             4
# MS APRN BC                   4
# RN, MSN, APRN-BC             4
# DO PA                        4
# P.A.- C.                     4
# BDS, DDS                     4
# MB BS                        4
# PERIODONTIST                 4
# MD PH D                      4
# APRN-BC, MSN                 4
# DMD PSC                      4
# AG-NP                        4
# MSN, AG-ACNP-BC              4
# NP-C, DNP                    4
# D.D.S.,PC                    4
# M D P A                      4
# APRN, FNP-C, ENP-C           4
# FNP-C,PMHNP-BC               4
# DNP, RN, NP-C                4
# D.D.S, M.S.D                 4
# PSYNP                        4
# M.D., P.C                    4
# RN MSN FNP-BC                4
# ACNP- BC                     4
# MD, MBA, MS                  4
# RNC,NP                       4
# FNP, APRN-BC                 4
# M.D.,F.A.C.O.G.              4
# D.M.D., MS                   4
# CNP, WHNP-BC                 4
# L.AC                         4
# M.DM                         4
# DNP, ANP                     4
# CNM NP                       4
# DNP, APRN-CNP, FNP-C         4
# MD., MPH.                    4
# O.D., M.S., F.A.A.O.         4
# ARNP, PHD                    4
# M.D., PH. D                  4
# APNP, FNP                    4
# B.D.S., M.S.                 4
# PHYSICIAN'S ASSISTAN         4
# FNP-C, DC                    4
# RN, BSN, FNP                 4
# D.O., FACOS                  4
# APRN, BC-FNP                 4
# APRN, DNP, PMHNP-BC          4
# RN, MSN, ARNP                4
# R.P.A.-C.                    4
# D.C., FNP                    4
# D.M.D., PH.D.                4
# D.O., MBA                    4
# MSN, FNP-BC, RN              4
# MS, PMHNP                    4
# DNP, RN, AGACNP-BC           4
# CRNP, CNM                    4
# DDS  MS                      4
# ARNP,FNP                     4
# CNM,ARNP                     4
# DNP, AGACNP-BC, APRN         4
# PCNP                         4
# M.D. LLC                     4
# MD, PHD, FACS                4
# F.N.P. - C                   4
# M.D.,F.A.C.S                 4
# DO, MS, MPH                  4
# MD PS                        4
# R.N., F.N.P.-B.C.            4
# N P                          4
# APRN, MSN                    4
# D.D.S. M.S.                  4
# AGNP-C, PMHNP-BC             4
# MD DO                        4
# MPAS, PA                     4
# MD LLC                       4
# MPAC                         4
# CNM, PMHNP-BC                4
# FNP, PMHNP-BC                4
# M.D., M.S.C.R.               4
# CRNP, PMHNP                  4
# ARNP - BC                    4
# MSN APRN NP-C                4
# MSN, APRN FNP-C              4
# OTR/L                        4
# D.O., PHARM.D.               4
# M .D.                        4
# ND LAC                       4
# DDS, MS, PC                  4
# D.D.S., D.M.D.               4
# DMD  MD                      4
# MC                           4
# MSN, FNP-C, RN               4
# O.D., M.B.A.                 4
# N.P.,                        4
# M.D., FCCP                   4
# NP-C, MSN, RN                4
# DMSC, MPAS, PA-C             4
# FNP NP-C                     4
# AGACNP-BC, APRN              4
# ANP-BC, RN                   4
# MB.BS                        4
# R.D.H                        4
# ...
# .D.O.                        1
# D.C., N,P.                   1
# ARNP RN CNS LMHC             1
# DMD BA                       1
# R.PH., BCGP                  1
# PA-C, RD, MMSC               1
# D.M.D..                      1
# DNP, APN, CS-FNP             1
# DDS, FDS RCS, MS             1
# D.D.S., M.D., M.B.A.         1
# DNP,ANP-BC, NE-BC            1
# PH.D, MPAP                   1
# B.D.S., M.S., M.P.S.         1
# DDS, MAGD, FICOI             1
# ARNP, PH.D., PC              1
# MSN,ANP, FNP-C               1
# ARNP FNPC                    1
# A.N.P., R.N.                 1
# APRN, CNS, CPNP              1
# NP, D.MIN.                   1
# RN,  NP                      1
# M.D., MRCPSYCH(UK)           1
# CNM, CDE                     1
# M.D.,S.C.                    1
# ERIN  MATHES                 1
# MD, FACP,FCCP, FAASM         1
# M.S., M.A., APRN-BC          1
# ND,CM                        1
# D.M.D.,M.D.S.                1
# JAMES CHIANG D.D.S.          1
# D.D.S. INC                   1
# MD, MHSA, FACEP              1
# MD,  SCD                     1
# M.D.,R.N                     1
# L.M.H.C., MSN                1
# DMD, M.MED.SC                1
# DP.M                         1
# ARNP, FNP, BC                1
# CRNP MSN NP-C                1
# CRNP PMHNP DNP               1
# PA,PHD                       1
# PAUL LEVENTHAL DDS           1
# DO PC AOAOS                  1
# RNCS PMH NP                  1
# PHD, APNP                    1
# MD AMC                       1
# NP-C, MSN,RNFA-CNOR          1
# FNP-C, ACNP-C                1
# APN (PMHNP)                  1
# DC, MSN, APRN                1
# AGACNP, WCC,DWC,OMS          1
# MSN, RN, NP                  1
# RN, CNM, CNP                 1
# NP-C DNP                     1
# GERALD SULLIVAN              1
# D.N.P., FNP-BC               1
# PHD, GNP BC                  1
# CNP, PH.D.                   1
# ARNP, M.ED, PMHNP-BC         1
# MB,CHB,DPHIL                 1
# APRN, BC, CS                 1
# APRN, MS, ACNP-BC            1
# RN, MSN, PPN                 1
# RN, NP-C (FNP)               1
# ERICA SCHNEIDER, DO          1
# APRN, AGAC-BC                1
# FNP-BC, ACNP, RN             1
# MD, M.BBS                    1
# R.N./N.P.                    1
# M.D./M.B.A                   1
# APRN-A-GNP-C                 1
# PA-C, CAQ-EM                 1
# APRN, AGPCNP-BC, CDE         1
# DNP, APRN, CNP, FNP          1
# MD, DABOM                    1
# M.D/PH.D                     1
# PA-C MS                      1
# OMS-IV                       1
# FNP, PMH-NP, DNP             1
# MSN, APRN, FNP-C,CPN         1
# MSN, RN, FNP-C, WOCN         1
# MSN, APRN , FNP - C          1
# NP, DC                       1
# B.D.S, M.S                   1
# ARNP-BC, MSN, BSN            1
# AP.R.N.                      1
# MSN, NP-C, AOCN              1
# MSN, BSN, RN, CRNP           1
# MD, D.M.D                    1
# APRN, CCNS-BC                1
# APN,  FNP-C                  1
# .N.P.                        1
# MSN, DNP, CRNP               1
# PA-C,DMSC,MSPAS,MPH          1
# BDS, MPA, MSD                1
# RPH  (PHARMACIST)            1
# MD, MPH, RD, CDCES           1
# MS, PA-C, MPH                1
# MS, ND                       1
# D.D.S., M.P.H                1
# ARNP-BC, PMD                 1
# MBBCH MCH                    1
# MD, MSA, FACP                1
# M.D.,FCCP,D,ABSM             1
# APRN-BC, WHCNP, MSN.         1
# DNP APRN NP--C               1
# RN/CNM                       1
# PMH/CNS/NP                   1
# CNP, PMHNP, RN               1
# MSN, NP-C, RN, PHN           1
# M.S., QMHP, CADC I           1
# M.D., FRCS(C)                1
# FRCS                         1
# APRN-FPA,CNS, FNP-BC         1
# PAT                          1
# MBBCHBS                      1
# DNP, AGNP, NP-C, AQH         1
# M.D., MRCP (UK)              1
# M.S.D.                       1
# R.N., N.P.P.                 1
# PH.D.RN,ANP-BC, FNP          1
# MSN, ACNS-BC, FNP-BC         1
# DNP, FNP-BC, DINPH           1
# D.C., N.D                    1
# APRN FNP, PMHNP              1
# ARNP, LAC                    1
# MAXILLOPROSTHODONTIS         1
# DMD, MMSC, PHD               1
# BM. B.CH., MRCP              1
# MICHAEL CLIFFORD MD          1
# MD,MBA,FACOG,FICS            1
# N.P. NURSE PRACTITIO         1
# D.N.P., ARNP                 1
# APRN, BC, MSN, ENP           1
# RNMSN                        1
# MPH, MPAS, PA-C, CPH         1
# N.P., R.D.                   1
# DDS, MS, FAGD, ABGD          1
# PH.D., PA                    1
# APRN FNP-BC MSN CDE          1
# APRN, CRNA, PMHNP-C          1
# ARNP, ND                     1
# DNP,  CPNP-PC                1
# DNP,FNP-BC,PMHNP-BC          1
# CPNP-AC/PC                   1
# DMD, FAGD, D.ABDSM           1
# DDS, PHD, MPH, MS            1
# CNM, APRN, MSN               1
# AGPC-NPC                     1
# NP-G                         1
# MS, APRN, AGCNS-BC           1
# DNP, FNP-BC, RN, BSN         1
# MS-HSM                       1
# RN, PMNHP-BC                 1
# OD RN                        1
# PHD, APRN, FNP               1
# MS  PA-C                     1
# O.D. P.C.                    1
# RN, CNS,  LP                 1
# R.N, APN, C                  1
# O.D. , P.C.                  1
# C.N.M., MSN                  1
# PHD, APRN,GNP,ANP-BC         1
# DPMFACFAS                    1
# APRN, FNP-C, PMHNP-C         1
# RN, BSN, AGPCNP              1
# FNP-BC, FPA                  1
# DNP, APRN, FNP - BC          1
# RN, MSN APRN FNP-C           1
# BDS, MHA, DMD, FICOI         1
# MSN, APRN-NP,WHNP-BC         1
# PA-C, ATC, CPH               1
# MCMS, PA-C                   1
# FNP-C, ACNPC-AG              1
# ND, RMSK, MA                 1
# MD, STUDENT                  1
# APRN - FNPC                  1
# OD, MEDVFL                   1
# MSN, RN, APRN, CEN           1
# CRNP-FNP-PMHNP-BC            1
# PPCNP-BC                     1
# APRN, CPNP-PC                1
# LPCC                         1
# RN,MSN,APRN,FNP-C            1
# MSN ARNP FNP                 1
# AGACNP, RN, APRN             1
# MSN. CRNP, NP-C              1
# RN, MS, CPNP                 1
# MSN, APN, NP-C, CCRN         1
# A/GNP-C                      1
# BDS, MDS, PHD CANDT          1
# APRN/FNP-BC                  1
# APN , CNP                    1
# DNP, PMHNP, GCNS             1
# APRN, CNP-C                  1
# DNP, PMHNP-BC, NP            1
# MSN, ACNPC-AG, CRNP          1
# MHA,MHS, PA-C                1
# DDS, MDS, MS, DMD            1
# RN-BSN, NP                   1
# ARNP; FNP                    1
# AGNPC-AG                     1
# DNP, PMHNP, AGNP             1
# RN, MNSC, AG-ACNP            1
# RN, MSN, CEN, FNP-C          1
# ARNP, FNP-BC, CNM            1
# ADULT PMHNP-BC               1
# D.C., P.A-C                  1
# MSN, CRNP, WHNP              1
# FNP, WHNP-BC                 1
# M.D. (H)                     1
# DR, CNP                      1
# MD, JD, MBA                  1
# MSN, PHN, PMHNP              1
# M.D. &. PH.D.                1
# MSN, APRN, CNS               1
# B.M.                         1
# ACNP DNP                     1
# D.D.S. M.S                   1
# DNP, MBA, PMHNP              1
# PA-C, MSBS                   1
# MSN,FNP,BSN RN               1
# MSN, ARNP, AGPCNP-C          1
# MSN, APRN, PMHNP-C           1
# PHARM. D., RPH.              1
# ANP, AGPCNP                  1
# LSW, RN                      1
# AGNP, PMHNP-BC               1
# FNP-BC, OCN, PMN             1
# MD,MPH,CIC                   1
# RN, CNS, LNP                 1
# D.V.M.,M.D., PH.D.           1
# RN  FNP C                    1
# MSN, AGPCNP-BC, WCC          1
# CRNP/PMH                     1
# PHD, PMHNP, FNP              1
# MD, FACP, FIDSA              1
# ND NATUROPATHIC PHYS         1
# RN MSN APNC NP               1
# O.D.,  PH.D.                 1
# D.D.S.. M.S.                 1
# BSN, MSN, CNP                1
# FNP, P.MH CNS                1
# M.D.;P.C.                    1
# MSSNP                        1
# M.D./M.S.                    1
# M.P.A-C                      1
# RN,BC,FNP                    1
# MD, MRCP (UK), FACC          1
# PA-C, CCP                    1
# AGNP,DNP                     1
# DNP, MSN, BSN, RN            1
# COMMUNITY PHARMACIST         1
# RBT                          1
# APRN, A-GNP, BC              1
# PHARM.D., M.A                1
# DNP-FPMHNP                   1
# DNP-FNP-C, APRN              1
# DNP, NP-C, AE-C              1
# M.D., PMD                    1
# DNP, APRN, AANP              1
# MD /MPHS                     1
# MSN-ED, FNP-BC, CEN          1
# APRN PMHCNS/NP-BC            1
# M.D.INC                      1
# CPNP, ARNP                   1
# M.D, , PH.D.                 1
# C.N.M., RN                   1
# MD,MRCSED,MS,MCH             1
# DNP, CPNP-PC                 1
# APRN BC CS                   1
# MSN, CPNP, FNP               1
# APRN, PCNS                   1
# M.P.C.                       1
# PAC, MPH                     1
# PHD  NP                      1
# CRNP,RN                      1
# B.A.,M.A., P.A.-C            1
# CRNA,FNP-C                   1
# R.N., A.P.N.,C.              1
# R PH PHARM D                 1
# MD FP                        1
# RN-BC, FNP, PMHNP            1
# WHNP, APN, MSN               1
# PHD APN C                    1
# MD, MPH, CMD                 1
# MD, FACC, FACP               1
# FNP-C DNP                    1
# CNP-A OCNP                   1
# D.M.D, PA                    1
# RN, MSN, ACNP/ACCNS          1
# CNM LM                       1
# APRN AGCNS-BC                1
# MSN, FNP, AANP-C             1
# RN, MSN, CS                  1
# MD, MBBS, FACC               1
# NP-C, APRN-C                 1
# MD FACC FACA FCCP            1
# DNP FNP, FPMHNP-BC           1
# EDD, ANP-BC, FNP-BC          1
# MD INTERNIST                 1
# MD, FACP, FACC               1
# PA-C,, RN                    1
# RN, FNP-BC, CNS-BC           1
# NP,PHN,RN                    1
# M.D.,MBA                     1
# M.D., RVS                    1
# M,D., PH.D.                  1
# MPH MSN APRN BC MSCN         1
# MD,  FACC                    1
# RNAP                         1
# JACK LIPPES                  1
# APN, WHNP, MS                1
# MMSC, MAE, PA-C, ATC         1
# D.O., MSPT                   1
# M . D                        1
# EDD, APRN, BC                1
# MD, DRPH, MBA                1
# PA, RN, EMT                  1
# D.O., MPT, MBA               1
# ANCP-C                       1
# DNP APNP                     1
# PHARMD, PHC, AAHIVP          1
# NPP-PC                       1
# SAC                          1
# M.D., M. P. H                1
# MSN-FNP-BC; PA-C             1
# PMHNP-BC, CRNP-BC            1
# ANP-C,  PMHNP-BC             1
# APRN MENTAL HEALTH           1
# MD, MHSC                     1
# PHD   NP-C                   1
# D.D.S,MPH                    1
# RN,MHP,MS                    1
# J.D., O.D.                   1
# F.N.P./PA-C                  1
# O.D., M..S                   1
# MSN, APRN-BC, CWOCN          1
# D.O., PA-C                   1
# ANP, NPP                     1
# MD PC FACP FAAA FACR         1
# R.PH.,PD                     1
# F.A.A.F.P.                   1
# A.P.R.N., B.C., N.P.         1
# M. D., F . A . C. S.         1
# FNP,MSN,IBCLC                1
# MN, APRN                     1
# DO, MFT                      1
# RG PH                        1
# M.D.,M.SC.                   1
# CNM NP RN                    1
# APNP, MSN, BSN               1
# GARY FREEDMAN, M.D.          1
# NP, RN, CNS                  1
# APRN MSN                     1
# PHARMD, RPH, PD              1
# D.M.D., M.SC.                1
# RN-CFNP                      1
# RN, MSN, NP-C, CHPN          1
# D M D.                       1
# P.A.A                        1
# DMD, MED, MD                 1
# DOM, L.AC, APNP              1
# PMHNP-BC, PNP-BC             1
# DNP, ANP-BC, RN              1
# RN ; NP                      1
# RN, MS, FNP-C, ACRN          1
# RN, MS, CNS, PNP             1
# M.D. , FACE                  1
# PNP, FNP, MSN                1
# DDS MSC APC                  1
# M.S., M.ED.,PA-C,ATC         1
# DC,ND                        1
# MD ,MPH                      1
# MEDICAL DOCTOR MD            1
# RN,MS, ANP-C, CNRN           1
# DNP, MS, FNP, BC-ADM         1
# MSN, PHD, RN, ARNP           1
# MSN/CNM                      1
# M.D.  FACR                   1
# CPNP APN                     1
# DC, NP                       1
# MD MS FACP                   1
# ENP/FNP                      1
# D O INC.                     1
# CS, APRN                     1
# NP/CNM                       1
# PMHCNS BC                    1
# PAC, MPAS, BBA               1
# NPA                          1
# APRN-RX, MSN, MPH            1
# MD,PHD,MPH                   1
# FNP-C, CGRN                  1
# G.N.P., APMHNP               1
# FNP. B-C                     1
# M.D., M.C.R.                 1
# M.B.B.S.,  M.S.              1
# MSN, RN, ANP, AGPCNP         1
# M.D., M.H.SC                 1
# AG-ACNP- BC                  1
# MSPAS, PHD, PA-C             1
# MSPAS, PA-C, ATC             1
# DNP APRN, CNP                1
# DNP, MHNP-BC                 1
# MA, MSN, LPC, APRN           1
# D.N.P, FNP-C                 1
# RN,MSN,CCRN,ACNP-BC          1
# APRN, PMHNP-BC , FNP         1
# CRNP, AGPCNP-BC              1
# RN, MSN, WHNP-BC, NP         1
# BDS, BSC                     1
# MHS, PA-C, RT(R)(VI)         1
# BMD PHD MS                   1
# DNP,FNP/BC                   1
# JOSEF VILLALUZ D.M.D         1
# RAMESH NEERPAT               1
# APRN  FNP                    1
# CNM,WHCNP                    1
# BSN,RN,MSN,WHNP-BC           1
# M.D.. M.SC.                  1
# RN, MSN,CNM, WHNP-BC         1
# ADN                          1
# DNP, PMHFNP                  1
# M.S.N., R.N., F.N.P.         1
# APRN NP-BC                   1
# DMD, MD, MS.ED               1
# M.D, FACE                    1
# MS RN ANP-BC CWOCN           1
# MSN, NP-C-APNP               1
# R.N., W.H.N.P.               1
# M.S, M.D                     1
# D.N.P., F.N.P., B.C.         1
# MSN  ADULT NURSE PRA         1
# BDS,MDS.MS                   1
# PAC FNPC                     1
# MD FASS                      1
# OT, DO                       1
# APRN, CNSPMH                 1
# NP(NURSE PRACTITIONE         1
# PHD, AAPRN, FNP-BC           1
# MD, PHD, MHA                 1
# MS, RN, FNP-BC, APNP         1
# JANE AUXIER, PA-C            1
# PA-C, AT, ATC                1
# DC, MSN,APRN, FNP-BC         1
# M.S.N., A.P.N., B.C.         1
# SCM                          1
# BS PHARMACY/PHARM D          1
# R.N., M.S., C.N.M.           1
# ACNP-BC, PMHNP-BC,RN         1
# RN, GNP-BC, PMHNP-BC         1
# NICOLAS KISSELL, MD          1
# RN,MSN,CNN,FNP               1
# PH.D, MS,APRN, ANP-C         1
# MSPA,.PA-C                   1
# MMSC, PA, RDN, CDE           1
# RN, ANP, BC                  1
# MD, MPP, MPH                 1
# RN C FNP                     1
# DNP, MSN, APRN, BC           1
# RN ANP-C                     1
# RN MN CPNP                   1
# MS, MMS, LPC, PA-C           1
# HELEN RIZZA, ARNP            1
# RNC MSN NP                   1
# DNP, NPP, PMHCNS-BC,         1
# FNP NP-PP                    1
# M.M.S PA-C                   1
# CGC                          1
# R.P.A.C                      1
# MS, ARNP, WHCNP              1
# M.D., FAAOS                  1
# MD MSMS                      1
# APRN, FPMHNP                 1
# MPA, PA-C, RRT               1
# RN, CNS/RXN                  1
# MDFACS                       1
# DOCTORATE OF NURSING         1
# PSYCHIATRIC-MENTAL H         1
# O.D., M.S., B.S.             1
# MNSC, APRN, FNP-C            1
# BSN, RN, APN, FNP-C          1
# M.D, M.P.H, M.S              1
# PA-                          1
# ARNP-FMP-BC, MSN             1
# MPH, MS, FNP-C               1
# APRN/RN                      1
# MSN,APRN,FNP-C,PCCN          1
# ANP, FNP-C                   1
# MSN, PMH-NP                  1
# DR,GLORIA NNAH               1
# RN, BSB, BSN                 1
# PHD, PMHNP, MPH, MS          1
# A-GCNP                       1
# M.D.., F.C.C.P.              1
# D.M.D, MSD                   1
# RN, MSN, CNM, IBCLC          1
# APRNX, FNP-BC                1
# M.D., MPH, MAT               1
# FNP-C, RN, ARNP              1
# DNP-FNP C                    1
# MD, MSCGH                    1
# M.D. / PH.D.                 1
# PH.D. MPAS PA-C              1
# RPH.D                        1
# MSN, CCRN, FNP-BC            1
# ARNP, FNP-C, PMHNP           1
# DNP, RXN, PMHNP-BC           1
# APRN, MSN-FNP-BC             1
# MSN, APRN, RN, FNP-C         1
# DNP, PMHNP - BC              1
# APNP, DNP                    1
# MD; MSN                      1
# AGACNP (DNP)                 1
# FNP-C; PMHNP- BC             1
# D.D.S., MPA, MAED            1

# %%
#drop data with specialties of less than 50 data points

credential_counts = df['Prscrbr_Crdntls'].value_counts()

# filter for specialties with 50 or more data points
valid_specialties = credential_counts[credential_counts >= 99].index

# keep only rows with valid specialties
df_dt = df[df['Prscrbr_Crdntls'].isin(valid_specialties)]

# %%
type_counts = df_dt['Prscrbr_Crdntls'].value_counts()
print(type_counts.to_string())
# Out:
# Prscrbr_Crdntls
# MD                     206905
# M.D.                   174655
# PA-C                    42362
# DDS                     28597
# DO                      27112
# D.O.                    24560
# NP                      24034
# O.D.                    17458
# PA                      16296
# FNP                     16066
# APRN                    15203
# D.D.S.                  15089
# DMD                     14846
# OD                      11643
# FNP-C                    9150
# ARNP                     8659
# PHARMD                   8262
# CRNP                     7265
# DPM                      6983
# M.D                      6934
# D.M.D.                   6382
# NP-C                     5908
# FNP-BC                   5190
# CNP                      4279
# RPH                      3914
# P.A.                     3626
# APN                      3205
# N.P.                     2681
# PMHNP                    2458
# D.P.M.                   2373
# PAC                      2344
# D.D.S                    2313
# PMHNP-BC                 2212
# PHARM.D.                 2023
# NURSE PRACTITIONER       1865
# MD, PHD                  1747
# CNM                      1585
# D.O                      1558
# D.M.D                    1520
# MD, MPH                  1435
# M.D., PH.D.              1371
# DNP                      1306
# ANP                      1137
# APNP                     1120
# PHARM D                  1073
# PHYSICIAN ASSISTANT      1045
# MBBS                      993
# APRN, FNP-C               966
# P.A.-C                    960
# APRN-CNP                  923
# RPA-C                     880
# M. D.                     852
# RN                        816
# PHARM.D                   691
# MSN, APRN, FNP-C          651
# AGACNP-BC                 618
# ACNP                      589
# M.D., M.P.H.              541
# MD PHD                    537
# CFNP                      519
# F.N.P.                    504
# N.D.                      501
# ND                        488
# WHNP                      484
# O.D                       477
# APRN, CNP                 416
# PA C                      416
# APRN, FNP-BC              412
# AGACNP                    410
# PHARMACIST                406
# R.PH.                     405
# P.A.-C.                   390
# MSN, FNP-C                388
# AGNP                      378
# M.D.,                     376
# DDS, MS                   372
# AGPCNP-BC                 354
# MD, MS                    352
# DDS, MD                   345
# PHARM. D.                 342
# ANP-BC                    330
# AGNP-C                    330
# D.P.M                     327
# WHNP-BC                   316
# DNP, FNP-C                303
# MPAS, PA-C                302
# CNS                       293
# DNP, FNP-BC               275
# APRN-BC                   268
# PHARMD.                   263
# PHARM D.                  263
# ACNP-BC                   261
# APRN, PMHNP-BC            257
# A.R.N.P.                  251
# MD, MBA                   249
# MSN, FNP-BC               248
# D.D.S., M.S.              243
# DMD, MD                   236
# MSN, APRN, FNP-BC         235
# M.D,                      229
# APRN, NP-C                225
# MD.                       218
# MD MPH                    213
# APRN, BC                  205
# M.D., M.S.                202
# DNP, APRN, FNP-C          201
# AGPCNP                    199
# MSN                       196
# ARNP-C                    194
# NPP                       191
# PHARMD, RPH               191
# PHARM. D                  181
# C.R.N.P.                  176
# M.B.B.S.                  174
# APRN, FNP                 174
# P.A                       173
# MSN, FNP                  170
# RN, FNP                   166
# ANP-C                     165
# RN, CNP                   165
# M.B.B.S                   163
# D.D.S., M.D.              162
# M.D., PHD                 162
# DNP, APRN, FNP-BC         157
# NMD                       157
# RN, NP                    156
# MS, PA-C                  156
# RN, FNP-C                 154
# M.D., MPH                 154
# A.P.R.N.                  151
# APRN FNP-C                150
# DNP, PMHNP-BC             149
# P.A.C.                    148
# O. D.                     148
# APRN-C                    147
# N.P                       146
# M D                       146
# DMD, MS                   145
# R.PH                      145
# RPAC                      143
# PA-C, ATC                 142
# APN-C                     137
# AG-ACNP                   136
# DDS MS                    133
# CRNA                      133
# MSN, PMHNP-BC             124
# C.N.P.                    123
# DO, MPH                   123
# FNPC                      123
# MSN, APRN, PMHNP-BC       121
# P.A-C                     120
# CRNP-PMH                  120
# MMS, PA-C                 119
# MSN, NP-C                 116
# RNP                       116
# PA-S                      114
# ACNPC-AG                  113
# C.N.M.                    110
# NP-BC                     107
# PHD                       106
# PA-C, MPAS                105
# CPNP                      105
# MD/PHD                    103
# DNP, APRN                 103
# M.D., PH.D                102
# ARNP-BC                   102
# GNP                       102
# APRN-NP                   101
# DNP, APRN, PMHNP-BC       100

# %%
# a lot of variation in format of reporting
#need to remap for consistency
# dictionary to map raw credentials to standardized labels
credential_mapping = {
    # MD
    'MD': 'MD', 'M.D.': 'MD', 'M.D': 'MD', 'M. D.': 'MD', 'MD, PHD': 'MD', 'MD PHD': 'MD',
    'MD, MPH': 'MD', 'M.D., PH.D.': 'MD', 'M.D., M.P.H.': 'MD', 'MD, MS': 'MD',
    'M.D.,': 'MD', 'M.D., PHD': 'MD', 'M.D., MPH': 'MD', 'MD.': 'MD', 'M.D,': 'MD',
    'M.D., M.S.': 'MD', 'MD MPH': 'MD', 'MD/PHD': 'MD',

    # DO
    'DO': 'DO', 'D.O.': 'DO', 'D.O': 'DO', 'DO, MPH': 'DO',

    # PA
    'PA-C': 'PA-C', 'PA': 'PA-C', 'P.A.': 'PA-C', 'PAC': 'PA-C', 'P.A': 'PA-C',
    'P.A.-C': 'PA-C', 'P.A.-C.': 'PA-C', 'PA C': 'PA-C', 'P.A-C': 'PA-C',
    'RPAC': 'PA-C', 'MPAS, PA-C': 'PA-C', 'PA-C, MPAS': 'PA-C', 'PA-C, ATC': 'PA-C',
    'MMS, PA-C': 'PA-C', 'MS, PA-C': 'PA-C', 'PHYSICIAN ASSISTANT': 'PA-C',

    # NP 
    'NP': 'NP', 'N.P.': 'NP', 'NP-C': 'NP', 'N.P': 'NP', 'NP-BC': 'NP',
    'NURSE PRACTITIONER': 'NP', 'RN, NP': 'NP', 'APRN, NP-C': 'NP', 'MSN, NP-C': 'NP',

    # FNP
    'FNP': 'FNP', 'FNP-C': 'FNP', 'FNP-BC': 'FNP', 'F.N.P.': 'FNP', 'CFNP': 'FNP',
    'FNPC': 'FNP', 'RN, FNP': 'FNP', 'RN, FNP-C': 'FNP', 'MSN, FNP-C': 'FNP',
    'MSN, FNP-BC': 'FNP', 'MSN, FNP': 'FNP',

    # APRN
    'APRN': 'APRN', 'APN': 'APRN', 'APRN, FNP-C': 'APRN', 'APRN-CNP': 'APRN',
    'APNP': 'APRN', 'APRN, CNP': 'APRN', 'APRN, FNP-BC': 'APRN', 'APRN, PMHNP-BC': 'APRN',
    'APRN-BC': 'APRN', 'APRN-C': 'APRN', 'APRN FNP-C': 'APRN', 'A.P.R.N.': 'APRN',
    'APRN, BC': 'APRN', 'APRN, FNP': 'APRN', 'APRN-NP': 'APRN',

    # CRNP
    'CRNP': 'CRNP', 'C.R.N.P.': 'CRNP', 'CRNP-PMH': 'CRNP',

    # ANP
    'ANP': 'ANP', 'ANP-BC': 'ANP', 'ANP-C': 'ANP',

    # PMHNP
    'PMHNP': 'PMHNP', 'PMHNP-BC': 'PMHNP', 'DNP, PMHNP-BC': 'PMHNP',

    # AGNP
    'AGNP': 'AGNP', 'AGPCNP': 'AGNP', 'AGACNP-BC': 'AGNP', 'AGNP-C': 'AGNP',
    'AGPCNP-BC': 'AGNP', 'AGACNP': 'AGNP', 'ACNPC-AG': 'AGNP',

    # CNP
    'CNP': 'CNP', 'C.N.P.': 'CNP', 'RN, CNP': 'CNP',

    # CNM
    'CNM': 'CNM', 'C.N.M.': 'CNM',

    # WHNP
    'WHNP': 'WHNP', 'WHNP-BC': 'WHNP',

    # CRNA
    'CRNA': 'CRNA',

    # DNP
    'DNP': 'DNP', 'DNP, FNP-C': 'DNP', 'DNP, FNP-BC': 'DNP', 'DNP, APRN, FNP-C': 'DNP',
    'DNP, APRN, FNP-BC': 'DNP', 'DNP, APRN': 'DNP', 'DNP, APRN, PMHNP-BC': 'DNP',

    # DDS
    'DDS': 'DDS', 'D.D.S.': 'DDS', 'D.D.S': 'DDS', 'DDS, MS': 'DDS', 'DDS MS': 'DDS',
    'DDS, MD': 'DDS', 'D.D.S., M.S.': 'DDS', 'D.D.S., M.D.': 'DDS',

    # DMD
    'DMD': 'DMD', 'D.M.D.': 'DMD', 'D.M.D': 'DMD', 'DMD, MD': 'DMD', 'DMD, MS': 'DMD',

    # OD
    'OD': 'OD', 'O.D.': 'OD', 'O.D': 'OD', 'O. D.': 'OD',

    # DPM
    'DPM': 'DPM', 'D.P.M.': 'DPM', 'D.P.M': 'DPM',

    # PharmD
    'PHARMD': 'PharmD', 'PHARM.D.': 'PharmD', 'PHARM.D': 'PharmD', 'PHARM D': 'PharmD',
    'PHARM. D.': 'PharmD', 'PHARM D.': 'PharmD', 'PHARM. D': 'PharmD', 'PHARMD.': 'PharmD',
    'PHARMD, RPH': 'PharmD', 'PHARMACIST': 'PharmD',

    # RPH
    'RPH': 'RPh', 'R.PH.': 'RPh', 'R.PH': 'RPh',

    # RN
    'RN': 'RN',

    # PHD
    'PHD': 'PhD', 'M.D., PH.D': 'PhD',

    # MBBS
    'MBBS': 'MBBS', 'M.B.B.S.': 'MBBS', 'M.B.B.S': 'MBBS',

    # ND
    'ND': 'ND', 'N.D.': 'ND', 'NMD': 'ND',
}

# %%
df_dt['Prscrbr_Crdntls_Cleaned'] = df_dt['Prscrbr_Crdntls'].map(credential_mapping).fillna(df_dt['Prscrbr_Crdntls'])
# Out:
# /var/folders/xp/jfl5n1qn405fcy_ccvcwy6mc0000gn/T/ipykernel_95365/3664401385.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dt['Prscrbr_Crdntls_Cleaned'] = df_dt['Prscrbr_Crdntls'].map(credential_mapping).fillna(df_dt['Prscrbr_Crdntls'])

# %%
type_counts = df_dt['Prscrbr_Crdntls_Cleaned'].value_counts()
print(type_counts.to_string())
# Out:
# Prscrbr_Crdntls_Cleaned
# MD                     396986
# PA-C                    68699
# DO                      53353
# DDS                     47254
# NP                      35238
# FNP                     32678
# OD                      29726
# APRN                    23698
# DMD                     23129
# PharmD                  13695
# DPM                      9683
# ARNP                     8659
# CRNP                     7561
# PMHNP                    4819
# CNP                      4567
# RPh                      4464
# DNP                      2445
# AGNP                     2402
# CNM                      1695
# ANP                      1632
# MBBS                     1330
# ND                       1146
# RPA-C                     880
# RN                        816
# WHNP                      800
# MSN, APRN, FNP-C          651
# ACNP                      589
# CNS                       293
# ACNP-BC                   261
# A.R.N.P.                  251
# MD, MBA                   249
# MSN, APRN, FNP-BC         235
# PhD                       208
# MSN                       196
# ARNP-C                    194
# NPP                       191
# P.A.C.                    148
# M D                       146
# APN-C                     137
# AG-ACNP                   136
# CRNA                      133
# MSN, PMHNP-BC             124
# MSN, APRN, PMHNP-BC       121
# RNP                       116
# PA-S                      114
# CPNP                      105
# GNP                       102
# ARNP-BC                   102

# %%
# reduce dataset to providers with at least 7500 data points

providers_to_keep = [
    'MD', 'PA-C', 'DO', 'DDS', 'NP', 'FNP',
    'OD', 'APRN', 'DMD', 'PharmD', 'DPM',
    'ARNP', 'CRNP'
]

df_dt = df_dt[df_dt['Prscrbr_Crdntls_Cleaned'].isin(providers_to_keep)]

# %%
# balance data, using both under and oversampling so that each provider type has 20,000 data points
from sklearn.utils import resample

balanced = []
for provider in providers_to_keep:
    subset = df_dt[df_dt['Prscrbr_Crdntls_Cleaned'] == provider]
    if len(subset) > 20000:
        # undersample
        sampled = resample(subset,
                           replace=False,
                           n_samples=20000,
                           random_state=42)
    else:
        # oversample
        sampled = resample(subset,
                           replace=True,
                           n_samples=20000,
                           random_state=42)
    balanced.append(sampled)

# combine into one balanced dataset
df_dt_2 = pd.concat(balanced)

# %%
# check work
type_counts = df_dt_2['Prscrbr_Crdntls_Cleaned'].value_counts()
print(type_counts)
# Out:
# Prscrbr_Crdntls_Cleaned
# MD        20000
# PA-C      20000
# DO        20000
# DDS       20000
# NP        20000
# FNP       20000
# OD        20000
# APRN      20000
# DMD       20000
# PharmD    20000
# DPM       20000
# ARNP      20000
# CRNP      20000
# Name: count, dtype: int64

# %%
df_dt_2.head()
# Out:
#         Prscrbr_Crdntls  Prscrbr_State_FIPS  Prscrbr_RUCA  \
# 580498               MD                24.0           1.0
# 1327788              MD                50.0           4.0
# 1234561            M.D.                27.0           7.0
# 593493     M.D., M.P.H.                39.0           1.0
# 1004531            M.D.                17.0           1.0
#
#                     Prscrbr_Type  Opioid_Tot_Clms  Opioid_Tot_Drug_Cst  \
# 580498         Internal Medicine              0.0                 0.00
# 1327788       Orthopedic Surgery             79.0               347.45
# 1234561  Obstetrics & Gynecology              0.0                 0.00
# 593493       Allergy/ Immunology              0.0                 0.00
# 1004531               Specialist             18.0              1324.08
#
#          Opioid_Tot_Suply  Opioid_Prscrbr_Rate  Opioid_LA_Tot_Clms  \
# 580498                0.0             0.000000                 0.0
# 1327788             359.0            40.932642                 0.0
# 1234561               0.0             0.000000                 0.0
# 593493                0.0             0.000000                 0.0
# 1004531             395.0            40.909091                 0.0
#
#         Prscrbr_Crdntls_Cleaned
# 580498                       MD
# 1327788                      MD
# 1234561                      MD
# 593493                       MD
# 1004531                      MD

# %%
df_dt_2=df_dt_2.drop(columns= 'Prscrbr_Crdntls', axis = 1)

# %%
df_dt_2.head()
# Out:
#          Prscrbr_State_FIPS  Prscrbr_RUCA             Prscrbr_Type  \
# 580498                 24.0           1.0        Internal Medicine
# 1327788                50.0           4.0       Orthopedic Surgery
# 1234561                27.0           7.0  Obstetrics & Gynecology
# 593493                 39.0           1.0      Allergy/ Immunology
# 1004531                17.0           1.0               Specialist
#
#          Opioid_Tot_Clms  Opioid_Tot_Drug_Cst  Opioid_Tot_Suply  \
# 580498               0.0                 0.00               0.0
# 1327788             79.0               347.45             359.0
# 1234561              0.0                 0.00               0.0
# 593493               0.0                 0.00               0.0
# 1004531             18.0              1324.08             395.0
#
#          Opioid_Prscrbr_Rate  Opioid_LA_Tot_Clms Prscrbr_Crdntls_Cleaned
# 580498              0.000000                 0.0                      MD
# 1327788            40.932642                 0.0                      MD
# 1234561             0.000000                 0.0                      MD
# 593493              0.000000                 0.0                      MD
# 1004531            40.909091                 0.0                      MD

# %%
specialty_counts = df_dt_2['Prscrbr_Type'].value_counts()
print(specialty_counts.to_string()) 

df_dt_2.drop(columns = 'Prscrbr_Type', axis = 1)
# Out:
# Prscrbr_Type
# Nurse Practitioner                                                98539
# Dentist                                                           36725
# Optometry                                                         19989
# Physician Assistant                                               19888
# Pharmacist                                                        19878
# Podiatry                                                          19729
# Family Practice                                                    8865
# Internal Medicine                                                  5639
# Student in an Organized Health Care Education/Training Program     3676
# Emergency Medicine                                                 3597
# Oral Surgery (Dentist only)                                        2257
# Psychiatry                                                         1541
# Obstetrics & Gynecology                                            1422
# Orthopedic Surgery                                                 1367
# General Surgery                                                    1259
# Psychiatry & Neurology                                             1084
# Cardiology                                                          978
# Ophthalmology                                                       860
# Dermatology                                                         732
# Neurology                                                           680
# Gastroenterology                                                    679
# Physical Medicine and Rehabilitation                                628
# Hospitalist                                                         540
# Urology                                                             510
# General Practice                                                    502
# Certified Clinical Nurse Specialist                                 483
# Pediatric Medicine                                                  477
# Pulmonary Disease                                                   459
# Otolaryngology                                                      450
# Nephrology                                                          444
# Anesthesiology                                                      399
# Endocrinology                                                       329
# Maxillofacial Surgery                                               320
# Infectious Disease                                                  306
# Rheumatology                                                        279
# Hematology-Oncology                                                 265
# Registered Nurse                                                    257
# Allergy/ Immunology                                                 250
# Interventional Cardiology                                           235
# Pain Management                                                     204
# Neuropsychiatry                                                     174
# Orthopaedic Surgery                                                 164
# Oral & Maxillofacial Surgery                                        161
# Neurosurgery                                                        157
# Osteopathic Manipulative Medicine                                   156
# Diagnostic Radiology                                                152
# Plastic and Reconstructive Surgery                                  149
# Interventional Pain Management                                      140
# Vascular Surgery                                                    131
# Sports Medicine                                                     130
# Specialist                                                          124
# Critical Care (Intensivists)                                         98
# Medical Oncology                                                     98
# Clinical Cardiac Electrophysiology                                   97
# Hospice and Palliative Care                                          94
# Hand Surgery                                                         89
# Radiation Oncology                                                   86
# Family Medicine                                                      78
# Colorectal Surgery (Proctology)                                      72
# Preventive Medicine                                                  71
# Certified Nurse Midwife                                              67
# Geriatric Medicine                                                   63
# Thoracic Surgery                                                     50
# Pharmacy                                                             50
# Pathology                                                            50
# Sleep Medicine                                                       40
# Plastic Surgery                                                      38
# Surgical Oncology                                                    35
# Interventional Radiology                                             32
# Advanced Heart Failure and Transplant Cardiology                     32
# Clinic/Center                                                        28
# Gynecological Oncology                                               28
# Cardiac Surgery                                                      25
# Hematology                                                           23
# Surgery                                                              23
# Thoracic Surgery (Cardiothoracic Vascular Surgery)                   22
# Addiction Medicine                                                   21
# Neurological Surgery                                                 15
# Micrographic Dermatologic Surgery                                    14
# Licensed Practical Nurse                                             14
# Nuclear Medicine                                                     13
# Pain Medicine                                                        11
# Undefined Physician type                                             11
# Geriatric Psychiatry                                                 11
# Personal Emergency Response Attendant                                 9
# Undersea and Hyperbaric Medicine                                      9
# General Acute Care Hospital                                           8
# Military Health Care Provider                                         8
# Legal Medicine                                                        8
# Medical Genetics and Genomics                                         7
# Physical Medicine & Rehabilitation                                    7
# Clinic or Group Practice                                              7
# Hospital                                                              6
# Counselor                                                             6
# Durable Medical Equipment & Medical Supplies                          6
# Pharmacy Technician                                                   6
# Colon & Rectal Surgery                                                5
# Chiropractic                                                          5
# Clinical Pharmacology                                                 5
# Other Clinic/Center                                                   4
# Emergency Medical Technician, Paramedic                               3
# Radiology                                                             3
# Peripheral Vascular Disease                                           2
# Psychologist, Clinical                                                2
# Oral Medicinist                                                       2
# Denturist                                                             2
# Hematopoietic Cell Transplantation and Cellular Therapy               2
# Neuromusculoskeletal Medicine, Sports Medicine                        2
# Chore Provider                                                        2
# Certified Registered Nurse Anesthetist (CRNA)                         2
# Specialist/Technologist, Other                                        1
# Rehabilitation Practitioner                                           1
# Radiologic Technologist                                               1
# Slide Preparation Facility                                            1
# Licensed Clinical Social Worker                                       1
# Physical Therapist in Private Practice                                1
# Home Health                                                           1
# Clinical Medical Laboratory                                           1
# Adult Congenital Heart Disease                                        1
# Dental Therapist                                                      1
# Unknown Supplier/Provider Specialty                                   1
# Psychoanalyst                                                         1
# Phlebology                                                            1
# Homemaker                                                             1
#          Prscrbr_State_FIPS  Prscrbr_RUCA  Opioid_Tot_Clms  \
# 580498                 24.0           1.0              0.0
# 1327788                50.0           4.0             79.0
# 1234561                27.0           7.0              0.0
# 593493                 39.0           1.0              0.0
# 1004531                17.0           1.0             18.0
# ...                     ...           ...              ...
# 808146                 42.0           1.0              0.0
# 224446                 42.0           1.0              0.0
# 316332                 24.0           1.0            853.0
# 388871                 42.0           1.0              0.0
# 1252904                 1.0           1.0              0.0
#
#          Opioid_Tot_Drug_Cst  Opioid_Tot_Suply  Opioid_Prscrbr_Rate  \
# 580498                  0.00               0.0             0.000000
# 1327788               347.45             359.0            40.932642
# 1234561                 0.00               0.0             0.000000
# 593493                  0.00               0.0             0.000000
# 1004531              1324.08             395.0            40.909091
# ...                      ...               ...                  ...
# 808146                  0.00               0.0             0.000000
# 224446                  0.00               0.0             0.000000
# 316332              34450.08           14207.0            78.042086
# 388871                  0.00               0.0             0.000000
# 1252904                 0.00               0.0             0.000000
#
#          Opioid_LA_Tot_Clms Prscrbr_Crdntls_Cleaned
# 580498                  0.0                      MD
# 1327788                 0.0                      MD
# 1234561                 0.0                      MD
# 593493                  0.0                      MD
# 1004531                 0.0                      MD
# ...                     ...                     ...
# 808146                  0.0                    CRNP
# 224446                  0.0                    CRNP
# 316332                195.0                    CRNP
# 388871                  0.0                    CRNP
# 1252904                 0.0                    CRNP
#
# [260000 rows x 8 columns]

# %%
# filter for specialties with 50 or more data points
valid_specs = specialty_counts[specialty_counts >= 99].index

# keep only rows with valid specialties
df_dt_2 = df_dt_2[df_dt_2['Prscrbr_Type'].isin(valid_specs)]

# %%
# create training and testing data, remove and save label
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification

# %%
#encode categorical variables
from sklearn.preprocessing import LabelEncoder

# initialize encoders
le_type = LabelEncoder()
le_cred = LabelEncoder()

# fit and transform the columns
df_dt_2['Prscrbr_Type_Encoded'] = le_type.fit_transform(df_dt_2['Prscrbr_Type'])
df_dt_2['Prscrbr_Crdntls_Encoded'] = le_cred.fit_transform(df_dt_2['Prscrbr_Crdntls_Cleaned'])

type_mapping = dict(zip(le_cred.transform(le_cred.classes_), le_cred.classes_))
print("Prscrbr_Type Mapping:")
print(type_mapping)

#drop categorical columns
df_dt_2 = df_dt_2.drop(['Prscrbr_Type', 'Prscrbr_Crdntls_Cleaned'], axis=1)
# Out:
# Prscrbr_Type Mapping:
# {0: 'APRN', 1: 'ARNP', 2: 'CRNP', 3: 'DDS', 4: 'DMD', 5: 'DO', 6: 'DPM', 7: 'FNP', 8: 'MD', 9: 'NP', 10: 'OD', 11: 'PA-C', 12: 'PharmD'}

# %%
df_dt_2.head(10)
# Out:
#          Prscrbr_State_FIPS  Prscrbr_RUCA  Opioid_Tot_Clms  \
# 580498                 24.0           1.0              0.0
# 1327788                50.0           4.0             79.0
# 1234561                27.0           7.0              0.0
# 593493                 39.0           1.0              0.0
# 1004531                17.0           1.0             18.0
# 1176766                13.0           1.0             14.0
# 1249108                12.0           1.0              0.0
# 1107861                51.0           1.0              0.0
# 599936                 26.0           1.0              0.0
# 1189293                20.0           4.0             31.0
#
#          Opioid_Tot_Drug_Cst  Opioid_Tot_Suply  Opioid_Prscrbr_Rate  \
# 580498                  0.00               0.0             0.000000
# 1327788               347.45             359.0            40.932642
# 1234561                 0.00               0.0             0.000000
# 593493                  0.00               0.0             0.000000
# 1004531              1324.08             395.0            40.909091
# 1176766                63.65             170.0             2.898551
# 1249108                 0.00               0.0             0.000000
# 1107861                 0.00               0.0             0.000000
# 599936                  0.00               0.0             0.000000
# 1189293               146.94              92.0            51.666667
#
#          Opioid_LA_Tot_Clms  Prscrbr_Type_Encoded  Prscrbr_Crdntls_Encoded
# 580498                  0.0                    49                        8
# 1327788                 0.0                    76                        8
# 1234561                 0.0                    69                        8
# 593493                  0.0                     3                        8
# 1004531                 0.0                   111                        8
# 1176766                 0.0                    49                        8
# 1249108                 0.0                    98                        8
# 1107861                 0.0                    99                        8
# 599936                  0.0                   114                        8
# 1189293                 0.0                    35                        8

# %%
training, testing = train_test_split(df_dt_2, test_size=.3)
##  Save the Labels and then remove them from the Training and Testing data
training_label = training["Prscrbr_Crdntls_Encoded"]
training=training.drop(["Prscrbr_Crdntls_Encoded"], axis=1)
testing_label = testing["Prscrbr_Crdntls_Encoded"]
testing=testing.drop(["Prscrbr_Crdntls_Encoded"], axis=1)

# %%
# initialize and train the Decision Tree model
clf = DecisionTreeClassifier(random_state=42,max_depth=15,min_samples_split=10)
clf.fit(training, training_label)  # Training the model with training data

# Step 3: Make predictions on the test set
prediction = clf.predict(testing)  # Predict labels for the test data

# Step 4: Evaluate the model
accuracy = accuracy_score(testing_label, prediction)
print(f"Accuracy: {accuracy:.2f}")

# Print additional evaluation metrics
print("\nClassification Report:")
print(classification_report(testing_label, prediction))

dt_cf = confusion_matrix(testing_label, prediction)
print("\nConfusion Matrix:")
print(confusion_matrix(testing_label, prediction))
# Out:
# Accuracy: 0.76
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.58      0.56      0.57      5859
#            1       0.76      0.79      0.78      5959
#            2       0.91      0.91      0.91      5940
#            3       0.70      0.79      0.74      6132
#            4       0.76      0.64      0.69      5986
#            5       0.60      0.65      0.63      6036
#            6       1.00      0.99      0.99      5968
#            7       0.48      0.51      0.50      6059
#            8       0.63      0.61      0.62      5962
#            9       0.53      0.47      0.50      5984
#           10       1.00      1.00      1.00      6059
#           11       1.00      0.99      1.00      6015
#           12       1.00      1.00      1.00      6041
#
#     accuracy                           0.76     78000
#    macro avg       0.76      0.76      0.76     78000
# weighted avg       0.76      0.76      0.76     78000
#
#
# Confusion Matrix:
# [[3267 1031   38    0    0   16    0 1051   13  442    0    1    0]
#  [ 709 4732   48    0    0   20    0  266   11  170    0    3    0]
#  [ 153   54 5428    0    1   14    0  146    5  137    0    2    0]
#  [   2    0    0 4843 1217   56    1    1   12    0    0    0    0]
#  [   1    0    0 2095 3830   49    1    0   10    0    0    0    0]
#  [   2    3    5    3    7 3930   14    3 2065    0    3    0    1]
#  [   0    0    0    0    0   43 5915    0   10    0    0    0    0]
#  [ 702  185  197    0    0   35    0 3120   16 1801    0    3    0]
#  [   2    1   11    3    5 2276   13    1 3645    0    0    0    5]
#  [ 809  203  254    0    0   23    0 1849   18 2826    0    2    0]
#  [   0    0    0    0    0    4    0    0    5    0 6050    0    0]
#  [   4    0    0    0    0   24    0    2   16    0    0 5969    0]
#  [   0    0    0    0    1   16    0    0    4    0    0    0 6020]]

# %%
## Create and display confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=dt_cf,display_labels=clf.classes_)
disp.plot()
plt.title("Provider Type Decision Tree Confusion Matrix")
plt.show()
